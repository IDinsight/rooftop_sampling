# %% [markdown]
# ## 0. Setup

# %%
INDIA_PROJECTED_CRS = "24378"

# %%
# set libraries to refresh
# %load_ext autoreload
# %autoreload 2

# %%
# general
from pathlib import Path
import numpy as np
import pandas as pd
import geopandas as gpd
from tqdm.notebook import tqdm

from os import listdir

# for plotting and coloring
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import math
import matplotlib.cm

# for handling S2 cells and downloading VIDA data
import boto3
from s2cell.s2cell import lat_lon_to_cell_id
import s2sphere
from shapely.geometry import Polygon

gpd.options.io_engine = "pyogrio"

# %%
from gridsample.utils import create_ids, create_gmap_links, save_shapefiles
# from gridsample.mapping import create_interactive_map

# %%
ROOT_DIR = Path("../")
DATA_DIR = ROOT_DIR / "data"
RAW_DATA_DIR = DATA_DIR / "01. Raw Data"
CLEANED_DATA_DIR = DATA_DIR / "02. Intermediate Outputs"
OUTPUT_DATA_DIR = DATA_DIR / "03. Final Outputs" / "pilot v3"
OUTPUT_DATA_DIR.mkdir(parents=True, exist_ok=True)

# %%
def generate_colormap(N):
    arr = np.arange(N) / N
    N_up = int(math.ceil(N / 7) * 7)
    arr.resize(N_up)
    arr = arr.reshape(7, N_up // 7).T.reshape(-1)
    ret = matplotlib.cm.hsv(arr)
    n = ret[:, 3].size
    a = n // 2
    b = n - a

    # Create arrays of exactly matching sizes
    for i in range(3):
        ret[0:a, i] *= np.linspace(0.2, 1, a)
    ret[a:, 3] *= np.linspace(1, 0.3, b)

    return ret[:N]  # Return only the requested number of colors

# %% [markdown]
# ## 1. Load Pilot Boundaries

# %%
# get all filepaths that end in `gpkg` inside the RAW_DATA_DIR / 0.1. MapSolve Boundaries
gdf = gpd.read_file(RAW_DATA_DIR / "99. Side Quest Data" / "Training circle - shillong.geojson")
gdf.to_crs(4326, inplace=True)

# Check there are 30 shapes
len(gdf)
# Out:
# 1

# %% [markdown]
# #### Add unique ID column

# %%
gdf["Unique Shape ID"] = create_ids(len(gdf), "SHAPE_")
gdf
# Out:
#                                             geometry Unique Shape ID
# 0  POLYGON ((91.88460 25.61807, 91.88032 25.61788...         SHAPE_1

# %% [markdown]
# ## 2. Download rooftops

# %% [markdown]
# ### Functions

# %% [markdown]
# #### S2 cell shapes

# %%
def s2_cell_id_to_shape(s2_cell_id):
    """
    Convert an S2 cell ID to a shapely polygon.

    Parameters:
    - s2_cell_id (int): The S2 cell ID

    Returns:
    - shapely.geometry.Polygon: Polygon representing the S2 cell
    """
    # Convert string to int if necessary
    if isinstance(s2_cell_id, str):
        s2_cell_id = int(s2_cell_id)

    # Create an S2 cell from the ID
    cell = s2sphere.CellId(s2_cell_id)
    cell = s2sphere.Cell(cell)

    # Extract the vertices of the cell
    vertices = []
    for i in range(4):
        vertex = cell.get_vertex(i)
        lat_lng = s2sphere.LatLng.from_point(vertex)
        vertices.append((lat_lng.lng().degrees, lat_lng.lat().degrees))

    # Close the polygon by repeating the first vertex
    vertices.append(vertices[0])

    # Create a shapely polygon
    return Polygon(vertices)


def s2_cell_ids_to_shapes_gdf(s2_cell_ids):
    """
    Convert a list of S2 cell IDs to a GeoDataFrame with polygon geometries.

    Parameters:
    - s2_cell_ids (list): List of S2 cell IDs

    Returns:
    - geopandas.GeoDataFrame: GeoDataFrame with S2 cells as polygons
    """
    geometries = []
    for s2_id in s2_cell_ids:
        polygon = s2_cell_id_to_shape(s2_id)
        geometries.append(polygon)

    return gpd.GeoDataFrame(
        {"s2_cell_id": s2_cell_ids, "geometry": geometries}, crs="EPSG:4326"
    )

# %% [markdown]
# #### Find IDs of overlapping S2 cells

# %%
def get_s2_cell_ids_from_points(points, level=6) -> list[int]:
    """
    Get S2 cell IDs for the given points at the specified level.
    """
    # check if crs is set to WGS84 (EPSG:4326)
    if points.crs is None or points.crs.to_string() != "EPSG:4326":
        raise ValueError("Points GeoDataFrame must be in WGS84 (EPSG:4326) CRS.")

    # convert points to S2 cell IDs
    s2_cell_id_list = points.geometry.apply(
        lambda geom: lat_lon_to_cell_id(geom.y, geom.x, level)
    )
    s2_cell_ids = s2_cell_id_list.unique().tolist()

    return s2_cell_ids


def get_s2_cell_ids(gdf, level=6) -> list[int]:
    """
    Get S2 cell IDs of S2 cells that overlap the given GeoDataFrame at the specified level.

    Iteratively checks if any area is not covered by an S2 cell and continues until all areas are covered.

    Parameters:
    - gdf: GeoDataFrame in WGS84 (EPSG:4326) CRS
    - level: int

    Returns:
    - list[int]: List of S2 cell IDs
    """

    # check if crs is set to WGS84 (EPSG:4326)
    if gdf.crs is None or gdf.crs.to_string() != "EPSG:4326":
        raise ValueError("GeoDataFrame must be in WGS84 (EPSG:4326) CRS.")

    # generate initial S2 cell IDs from the GeoDataFrame centroids
    points = gdf.geometry.centroid.to_frame(name="geometry")
    s2_cell_ids = get_s2_cell_ids_from_points(points, level=level)

    # get initial S2 cell shapes and check for full coverage
    s2_cell_shapes = s2_cell_ids_to_shapes_gdf(s2_cell_ids)
    leftover_shapes = gdf.difference(s2_cell_shapes.unary_union)
    leftover_shapes = leftover_shapes[~leftover_shapes.is_empty]

    print(f"Shapes with spillover after round 1: {len(leftover_shapes)}")

    step = 2
    while len(leftover_shapes) > 0:
        # get new s2 cell IDs from the leftover shapes
        points_new = leftover_shapes.geometry.centroid.to_frame(name="geometry")
        s2_cell_ids_new = get_s2_cell_ids_from_points(points_new, level=level)

        # get new s2 cell shapes
        s2_cell_shapes = s2_cell_ids_to_shapes_gdf(s2_cell_ids_new)
        leftover_shapes = leftover_shapes.difference(s2_cell_shapes.unary_union)
        leftover_shapes = leftover_shapes[~leftover_shapes.is_empty]

        # add new s2 cell IDs to the existing list
        s2_cell_ids = s2_cell_ids + s2_cell_ids_new

        print(f"Shapes with spillover after round {step}: {len(leftover_shapes)}")
        step += 1

    return s2_cell_ids

# %% [markdown]
# #### Auto-download rooftop data by S2 cell ID

# %%
def download_VIDA_rooftops_data_by_s2_single(
    s2_cell_id: int, country_iso_code: str, target_data_dir: Path
) -> None:
    """
    Download S2 rooftops data for a given S2 cell ID from the VIDA S3 bucket. URL:
    https://beta.source.coop/vida/google-microsoft-open-buildings/geoparquet/by_country_s2/country_iso=IND/
    """

    s2_rooftops_path = target_data_dir / f"{s2_cell_id}.parquet"

    if s2_rooftops_path.exists():
        print(f"File {s2_cell_id} already exists.")
    else:
        print(f"Downloading file for S2 cell ID: {s2_cell_id}")
        s2_rooftops_path.parent.mkdir(parents=True, exist_ok=True)
        s3 = boto3.client("s3", endpoint_url="https://data.source.coop")
        try:
            s3.download_file(
                "vida",
                f"google-microsoft-open-buildings/geoparquet/by_country_s2/country_iso={country_iso_code}/{s2_cell_id}.parquet",
                str(s2_rooftops_path),
            )
            print(f"File {s2_cell_id} downloaded.")
        except Exception as e:
            raise RuntimeError(
                f"Failed to download file for S2 cell ID {s2_cell_id}: {e}"
            )


def download_VIDA_rooftops_data_by_s2(
    s2_cell_ids: list[int], country_iso_code: str, target_data_dir: Path
) -> None:
    """
    Download S2 rooftops data for multiple S2 cell IDs

    Parameters:
    - s2_cell_ids: list of S2 cell IDs
    - country_iso_code: ISO code of the country (e.g., "IND" for India)
    - target_data_dir: directory to save the downloaded data
    """

    for s2_cell_id in tqdm(s2_cell_ids, desc="Downloading rooftops by S2 cell"):
        download_VIDA_rooftops_data_by_s2_single(
            s2_cell_id, country_iso_code, target_data_dir
        )

# %% [markdown]
# ### Run

# %% [markdown]
# #### Identify S2 cell IDs

# %%
s2_cell_ids = get_s2_cell_ids(gdf, level=6)  # get_s2_cell_ids(boundaries_gdf)
len(s2_cell_ids)
# Out:
# Shapes with spillover after round 1: 0
# /var/folders/99/cwxq7sdx5d94rqxj57_crqbc0000gn/T/ipykernel_4762/1927699269.py:37: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   points = gdf.geometry.centroid.to_frame(name="geometry")
# 1

# %%
s2_cell_ids
# Out:
# [3985967145199599616]

# %% [markdown]
# #### Check if identified cells cover all areas of interest

# %%
s2_cells_gdf = s2_cell_ids_to_shapes_gdf(s2_cell_ids)

# %%
# Does the S2 cell cover the entire area of the boundaries?
uncovered_area = gdf.unary_union.difference(s2_cells_gdf.unary_union).area
print(f"{uncovered_area} square degrees area not covered by an S2 cell")
# Out:
# 0.0 square degrees area not covered by an S2 cell

# %%
# Plot the S2 cells and the boundary
fig, ax = plt.subplots(1, 1, figsize=(6, 6))
gdf.boundary.plot(ax=ax, color="black", linewidth=1)
s2_cells_gdf.plot(ax=ax, facecolor="none", edgecolor="red", alpha=0.7)
plt.title("S2 Cells Level 6 Coverage")
plt.tight_layout()
plt.show()

# %%
s2_gdf_join = s2_cells_gdf.sjoin(
    gdf[["Unique Shape ID", "geometry"]], how="inner", predicate="intersects"
).drop(columns="index_right").drop_duplicates()
s2_gdf_join
# Out:
#             s2_cell_id                                           geometry  \
# 0  3985967145199599616  POLYGON ((91.21213 24.13915, 92.46041 24.12422...
#
#   Unique Shape ID
# 0         SHAPE_1

# %% [markdown]
# #### Download the S2 cells

# %%
download_VIDA_rooftops_data_by_s2(s2_cell_ids, "IND", RAW_DATA_DIR / "02. Rooftop Data")
# Out:
# Downloading rooftops by S2 cell:   0%|          | 0/1 [00:00<?, ?it/s]
# File 3985967145199599616 already exists.

# %% [markdown]
# ## 6. Load rooftops and match to areas

# %%
def get_matched_rooftop_centroids_from_s2_file(
    s2_cell_id: int, boundaries_gdf: gpd.GeoDataFrame
) -> gpd.GeoDataFrame:
    """
    Get rooftops from the S2 cell file that match the boundaries:
    1. loads the rooftops data for the specified S2 cell ID
    2. filters the rooftops to only those that intersect with the boundaries
    3. returns a GeoDataFrame of the matched rooftops centroids with unique IDs

    Parameters:
    - s2_cell_id (int): The S2 cell ID to filter rooftops for.
    - boundaries_gdf (gpd.GeoDataFrame): The GeoDataFrame containing the boundaries.
    """

    # load the rooftops data for the S2 cell
    s2_rooftops_path = RAW_DATA_DIR / "02. Rooftop Data" / f"{s2_cell_id}.parquet"
    s2_rooftops_gdf = gpd.read_parquet(s2_rooftops_path)

    # replace polygons with just the centroid of the rooftops
    s2_rooftop_centroids_gdf = s2_rooftops_gdf.set_geometry(
        s2_rooftops_gdf.geometry.centroid
    )

    # filter the boundaries dataset to only the shapes that overlap the S2 cell
    s2_cell_polygon = s2_cell_id_to_shape(s2_cell_id)
    boundaries_gdf_s2_overlap = boundaries_gdf[
        boundaries_gdf.intersects(s2_cell_polygon)
    ]

    # perform a spatial join to filter and add area metadata to the rooftops
    matched_rooftop_centroids_gdf = gpd.sjoin(
        s2_rooftop_centroids_gdf,
        boundaries_gdf_s2_overlap,
        how="inner",
        predicate="within",
    ).drop(columns=["index_right"])

    # add IDs to each rooftop
    matched_rooftop_centroids_gdf["s2_rooftop_id"] = create_ids(
        len(matched_rooftop_centroids_gdf), f"S2_{s2_cell_id}_ROOFTOP_"
    )

    return matched_rooftop_centroids_gdf

# %%
try:
    # Get matched rooftops for each S2 cell
    matched_rooftop_centroids_gdf_list = []
    for s2_cell_id in tqdm(s2_cell_ids):
        matched_rooftop_centroids_gdf = get_matched_rooftop_centroids_from_s2_file(
            s2_cell_id, gdf
        )
        matched_rooftop_centroids_gdf_list.append(matched_rooftop_centroids_gdf)
    matched_rooftop_centroids_gdf = pd.concat(
        matched_rooftop_centroids_gdf_list, ignore_index=True
    )

    # Save the matched rooftops data
    save_shapefiles(
        matched_rooftop_centroids_gdf,
        CLEANED_DATA_DIR / "01. Matched Rooftop Data" / "pilot_v3",
        "matched_rooftops",
        ["parquet"],
    )
except Exception as e:
    print(f"Error processing: {e}")
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# /var/folders/99/cwxq7sdx5d94rqxj57_crqbc0000gn/T/ipykernel_4762/207331629.py:21: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   s2_rooftops_gdf.geometry.centroid

# %%
matched_rooftop_centroids_gdf
# Out:
#         boundary_id  bf_source  confidence  area_in_meters  \
# 0                56  microsoft         NaN         28.7239
# 1                56     google      0.8307        159.2463
# 2                56     google      0.7185         33.3985
# 3                56  microsoft         NaN         48.1248
# 4                56     google      0.7285         62.1944
# ...             ...        ...         ...             ...
# 101569           56     google      0.8102         21.2871
# 101570           56     google      0.7224         43.7984
# 101571           56     google      0.6920         23.6320
# 101572           56     google      0.6718         62.0331
# 101573           56     google      0.7581         38.6890
#
#                       s2_id country_iso                   geometry   geohash  \
# 0       3985967145199599616         IND  POINT (91.84566 25.56365)  wh933vxz
# 1       3985967145199599616         IND  POINT (91.84408 25.56510)  wh933vyz
# 2       3985967145199599616         IND  POINT (91.84419 25.56505)  wh933vyz
# 3       3985967145199599616         IND  POINT (91.84503 25.56423)  wh933vzd
# 4       3985967145199599616         IND  POINT (91.84465 25.56464)  wh933vzh
# ...                     ...         ...                        ...       ...
# 101569  3985967145199599616         IND  POINT (91.91174 25.60827)  wh93etb4
# 101570  3985967145199599616         IND  POINT (91.91168 25.60830)  wh93etb5
# 101571  3985967145199599616         IND  POINT (91.91182 25.60830)  wh93etb5
# 101572  3985967145199599616         IND  POINT (91.91260 25.60802)  wh93etb9
# 101573  3985967145199599616         IND  POINT (91.91254 25.60809)  wh93etb9
#
#                                                      bbox Unique Shape ID  \
# 0       {'xmin': 91.84563921944455, 'ymin': 25.5636188...         SHAPE_1
# 1       {'xmin': 91.8439830193152, 'ymin': 25.56502781...         SHAPE_1
# 2       {'xmin': 91.8441531644479, 'ymin': 25.56501536...         SHAPE_1
# 3       {'xmin': 91.84497014105574, 'ymin': 25.5641845...         SHAPE_1
# 4       {'xmin': 91.8445932328102, 'ymin': 25.56458039...         SHAPE_1
# ...                                                   ...             ...
# 101569  {'xmin': 91.9117206864806, 'ymin': 25.60824640...         SHAPE_1
# 101570  {'xmin': 91.9116433246393, 'ymin': 25.60826015...         SHAPE_1
# 101571  {'xmin': 91.9117891254649, 'ymin': 25.60827979...         SHAPE_1
# 101572  {'xmin': 91.9125462909463, 'ymin': 25.60797156...         SHAPE_1
# 101573  {'xmin': 91.9124941456508, 'ymin': 25.60804842...         SHAPE_1
#
#                                 s2_rooftop_id
# 0       S2_3985967145199599616_ROOFTOP_000001
# 1       S2_3985967145199599616_ROOFTOP_000002
# 2       S2_3985967145199599616_ROOFTOP_000003
# 3       S2_3985967145199599616_ROOFTOP_000004
# 4       S2_3985967145199599616_ROOFTOP_000005
# ...                                       ...
# 101569  S2_3985967145199599616_ROOFTOP_101570
# 101570  S2_3985967145199599616_ROOFTOP_101571
# 101571  S2_3985967145199599616_ROOFTOP_101572
# 101572  S2_3985967145199599616_ROOFTOP_101573
# 101573  S2_3985967145199599616_ROOFTOP_101574
#
# [101574 rows x 11 columns]

# %%
matched_rooftop_centroids_gdf.sample(1000).plot(
    cmap=ListedColormap(generate_colormap(len(matched_rooftop_centroids_gdf))),
)
# Out:
# <Axes: >

# %% [markdown]
# ## 7. Load matched rooftops

# %%
matched_rooftops_gdf = gpd.read_parquet(
    CLEANED_DATA_DIR / "01. Matched Rooftop Data" / "pilot_v3" / "matched_rooftops.parquet"
)

# %%
matched_rooftops_gdf
# Out:
#         boundary_id  bf_source  confidence  area_in_meters  \
# 0                56  microsoft         NaN         28.7239
# 1                56     google      0.8307        159.2463
# 2                56     google      0.7185         33.3985
# 3                56  microsoft         NaN         48.1248
# 4                56     google      0.7285         62.1944
# ...             ...        ...         ...             ...
# 101569           56     google      0.8102         21.2871
# 101570           56     google      0.7224         43.7984
# 101571           56     google      0.6920         23.6320
# 101572           56     google      0.6718         62.0331
# 101573           56     google      0.7581         38.6890
#
#                       s2_id country_iso                   geometry   geohash  \
# 0       3985967145199599616         IND  POINT (91.84566 25.56365)  wh933vxz
# 1       3985967145199599616         IND  POINT (91.84408 25.56510)  wh933vyz
# 2       3985967145199599616         IND  POINT (91.84419 25.56505)  wh933vyz
# 3       3985967145199599616         IND  POINT (91.84503 25.56423)  wh933vzd
# 4       3985967145199599616         IND  POINT (91.84465 25.56464)  wh933vzh
# ...                     ...         ...                        ...       ...
# 101569  3985967145199599616         IND  POINT (91.91174 25.60827)  wh93etb4
# 101570  3985967145199599616         IND  POINT (91.91168 25.60830)  wh93etb5
# 101571  3985967145199599616         IND  POINT (91.91182 25.60830)  wh93etb5
# 101572  3985967145199599616         IND  POINT (91.91260 25.60802)  wh93etb9
# 101573  3985967145199599616         IND  POINT (91.91254 25.60809)  wh93etb9
#
#                                                      bbox Unique Shape ID  \
# 0       {'xmax': 91.84568883798983, 'xmin': 91.8456392...         SHAPE_1
# 1       {'xmax': 91.844167686975, 'xmin': 91.843983019...         SHAPE_1
# 2       {'xmax': 91.844235204746, 'xmin': 91.844153164...         SHAPE_1
# 3       {'xmax': 91.84508093730052, 'xmin': 91.8449701...         SHAPE_1
# 4       {'xmax': 91.8447043207205, 'xmin': 91.84459323...         SHAPE_1
# ...                                                   ...             ...
# 101569  {'xmax': 91.9117680509952, 'xmin': 91.91172068...         SHAPE_1
# 101570  {'xmax': 91.9117124866219, 'xmin': 91.91164332...         SHAPE_1
# 101571  {'xmax': 91.91184760619501, 'xmin': 91.9117891...         SHAPE_1
# 101572  {'xmax': 91.912669884183, 'xmin': 91.912546290...         SHAPE_1
# 101573  {'xmax': 91.9125816456483, 'xmin': 91.91249414...         SHAPE_1
#
#                                 s2_rooftop_id
# 0       S2_3985967145199599616_ROOFTOP_000001
# 1       S2_3985967145199599616_ROOFTOP_000002
# 2       S2_3985967145199599616_ROOFTOP_000003
# 3       S2_3985967145199599616_ROOFTOP_000004
# 4       S2_3985967145199599616_ROOFTOP_000005
# ...                                       ...
# 101569  S2_3985967145199599616_ROOFTOP_101570
# 101570  S2_3985967145199599616_ROOFTOP_101571
# 101571  S2_3985967145199599616_ROOFTOP_101572
# 101572  S2_3985967145199599616_ROOFTOP_101573
# 101573  S2_3985967145199599616_ROOFTOP_101574
#
# [101574 rows x 11 columns]

# %% [markdown]
# ## 8. Sample rooftops

# %% [markdown]
# ### Do the sampling

# %%
# Define the base number of rooftops per shape
ROOFTOPS_PER_SHAPE = 30

sampled_rooftops = matched_rooftops_gdf.groupby(
    "Unique Shape ID", group_keys=False
).apply(
    lambda x: x.sample(
        n=ROOFTOPS_PER_SHAPE,
        random_state=42
    )
)

# %%
len(sampled_rooftops)/ROOFTOPS_PER_SHAPE
# Out:
# 1.0

# %%
sampled_rooftops.plot(
    figsize=(8, 8),
    cmap="tab20",
    edgecolor="black",
    linewidth=0.5,
    legend=True,
)
# Out:
# <Axes: >

# %% [markdown]
# ### Add sample-level rooftop numbering ID columns

# %%
# Rooftop number within each shape
sampled_rooftops["Rooftop ID Per Shape"] = (
    sampled_rooftops.groupby("Unique Shape ID").cumcount() + 1
)

sampled_rooftops["Unique Rooftop ID"] = sampled_rooftops.apply(
    lambda row: f"{row['Unique Shape ID']}_ROOFTOP_{row['Rooftop ID Per Shape']}",
    axis=1,
)

# %%
sampled_rooftops
# Out:
#        boundary_id  bf_source  confidence  area_in_meters  \
# 16046           56     google      0.7912         29.7055
# 43512           56     google      0.8293        108.8539
# 37012           56     google      0.7206         21.1570
# 92514           56     google      0.7429         15.6150
# 81910           56     google      0.7958         34.7692
# 84337           56     google      0.7014         47.8685
# 90562           56     google      0.8838         80.1483
# 21303           56     google      0.6645         41.5885
# 39968           56     google      0.8016        160.1028
# 58230           56     google      0.7993        125.4720
# 90332           56     google      0.6929         20.1815
# 40408           56     google      0.7930        119.8637
# 22481           56     google      0.9095        486.5726
# 48972           56     google      0.8019         21.8889
# 47768           56     google      0.8040         49.9388
# 66938           56     google      0.7296         18.1005
# 48885           56     google      0.8409         54.7498
# 53090           56     google      0.8790        133.8307
# 42906           56     google      0.6680         21.7964
# 93856           56     google      0.6899         23.0600
# 95363           56     google      0.7796        107.4983
# 70885           56     google      0.7942         99.7720
# 51053           56  microsoft         NaN        139.4219
# 63659           56     google      0.8775        512.0237
# 95145           56     google      0.7367         30.6359
# 134             56     google      0.6697         49.5332
# 90165           56     google      0.8689         61.0763
# 47447           56     google      0.6938         22.5723
# 80405           56     google      0.8315        105.2878
# 35259           56     google      0.8833        115.6754
#
#                      s2_id country_iso                   geometry   geohash  \
# 16046  3985967145199599616         IND  POINT (91.88287 25.55815)  wh936uep
# 43512  3985967145199599616         IND  POINT (91.91445 25.55783)  wh937sdj
# 37012  3985967145199599616         IND  POINT (91.89840 25.57081)  wh937pn2
# 92514  3985967145199599616         IND  POINT (91.91746 25.57675)  wh93e8h7
# 81910  3985967145199599616         IND  POINT (91.89834 25.58425)  wh93e1qr
# 84337  3985967145199599616         IND  POINT (91.90148 25.58419)  wh93e32w
# 90562  3985967145199599616         IND  POINT (91.91135 25.58936)  wh93e6ru
# 21303  3985967145199599616         IND  POINT (91.87899 25.56526)  wh936y00
# 39968  3985967145199599616         IND  POINT (91.90633 25.56977)  wh937qu4
# 58230  3985967145199599616         IND  POINT (91.87151 25.58330)  wh93d96c
# 90332  3985967145199599616         IND  POINT (91.91033 25.58787)  wh93e6ph
# 40408  3985967145199599616         IND  POINT (91.90979 25.57002)  wh937qys
# 22481  3985967145199599616         IND  POINT (91.88624 25.56887)  wh936ytt
# 48972  3985967145199599616         IND  POINT (91.92025 25.57299)  wh937xqm
# 47768  3985967145199599616         IND  POINT (91.91279 25.57529)  wh937xbf
# 66938  3985967145199599616         IND  POINT (91.86966 25.59288)  wh93de13
# 48885  3985967145199599616         IND  POINT (91.92173 25.57169)  wh937xpm
# 53090  3985967145199599616         IND  POINT (91.86755 25.59449)  wh93d7rf
# 42906  3985967145199599616         IND  POINT (91.91557 25.55526)  wh937s4y
# 93856  3985967145199599616         IND  POINT (91.92156 25.58244)  wh93e9ph
# 95363  3985967145199599616         IND  POINT (91.92113 25.58951)  wh93edqv
# 70885  3985967145199599616         IND  POINT (91.88093 25.59355)  wh93dg1t
# 134    SHAPE_1_ROOFTOP_26
# 90165  SHAPE_1_ROOFTOP_27
# 47447  SHAPE_1_ROOFTOP_28
# 80405  SHAPE_1_ROOFTOP_29
# 35259  SHAPE_1_ROOFTOP_30

# %% [markdown]
# ### Add gmap link

# %%
sampled_rooftops["latitude"] = sampled_rooftops.geometry.y
sampled_rooftops["longitude"] = sampled_rooftops.geometry.x
sampled_rooftops["gmap_link"] = create_gmap_links(
    df=sampled_rooftops,
    lat_name="latitude",
    lon_name="longitude",
)

# %% [markdown]
# ### Select only useful columns

# %%
sampled_rooftops.columns
# Out:
# Index(['boundary_id', 'bf_source', 'confidence', 'area_in_meters', 's2_id',
#        'country_iso', 'geometry', 'geohash', 'bbox', 'Unique Shape ID',
#        's2_rooftop_id', 'Rooftop ID Per Shape', 'Unique Rooftop ID',
#        'latitude', 'longitude', 'gmap_link'],
#       dtype='object')

# %%
chosen_cols = [
    "Unique Rooftop ID",
    "Unique Shape ID",
    "Rooftop ID Per Shape",
    "latitude",
    "longitude",
    "gmap_link",
    "geometry",
    # ## rooftop info
    # "boundary_id",
    # "bf_source",
    # "confidence",
    # "area_in_meters",
    # "s2_id",
    # "country_iso",
    # "geohash",
    # "bbox",
]

# %%
sampled_rooftops_organised_gdf = sampled_rooftops[chosen_cols]

# %%
sampled_rooftops_organised_gdf
# Out:
#         Unique Rooftop ID Unique Shape ID  Rooftop ID Per Shape   latitude  \
# 16046   SHAPE_1_ROOFTOP_1         SHAPE_1                     1  25.558152
# 43512   SHAPE_1_ROOFTOP_2         SHAPE_1                     2  25.557829
# 37012   SHAPE_1_ROOFTOP_3         SHAPE_1                     3  25.570808
# 92514   SHAPE_1_ROOFTOP_4         SHAPE_1                     4  25.576755
# 81910   SHAPE_1_ROOFTOP_5         SHAPE_1                     5  25.584249
# 84337   SHAPE_1_ROOFTOP_6         SHAPE_1                     6  25.584191
# 90562   SHAPE_1_ROOFTOP_7         SHAPE_1                     7  25.589357
# 21303   SHAPE_1_ROOFTOP_8         SHAPE_1                     8  25.565261
# 39968   SHAPE_1_ROOFTOP_9         SHAPE_1                     9  25.569768
# 58230  SHAPE_1_ROOFTOP_10         SHAPE_1                    10  25.583298
# 90332  SHAPE_1_ROOFTOP_11         SHAPE_1                    11  25.587866
# 40408  SHAPE_1_ROOFTOP_12         SHAPE_1                    12  25.570023
# 22481  SHAPE_1_ROOFTOP_13         SHAPE_1                    13  25.568867
# 48972  SHAPE_1_ROOFTOP_14         SHAPE_1                    14  25.572991
# 47768  SHAPE_1_ROOFTOP_15         SHAPE_1                    15  25.575289
# 66938  SHAPE_1_ROOFTOP_16         SHAPE_1                    16  25.592878
# 48885  SHAPE_1_ROOFTOP_17         SHAPE_1                    17  25.571693
# 53090  SHAPE_1_ROOFTOP_18         SHAPE_1                    18  25.594493
# 42906  SHAPE_1_ROOFTOP_19         SHAPE_1                    19  25.555262
# 93856  SHAPE_1_ROOFTOP_20         SHAPE_1                    20  25.582435
# 95363  SHAPE_1_ROOFTOP_21         SHAPE_1                    21  25.589508
# 40408  POINT (91.90979 25.57002)
# 22481  POINT (91.88624 25.56887)
# 48972  POINT (91.92025 25.57299)
# 47768  POINT (91.91279 25.57529)
# 66938  POINT (91.86966 25.59288)
# 48885  POINT (91.92173 25.57169)
# 53090  POINT (91.86755 25.59449)
# 42906  POINT (91.91557 25.55526)
# 93856  POINT (91.92156 25.58244)
# 95363  POINT (91.92113 25.58951)
# 70885  POINT (91.88093 25.59355)
# 51053  POINT (91.85235 25.57622)
# 63659  POINT (91.88247 25.58463)
# 95145  POINT (91.91485 25.59176)
# 134    POINT (91.84503 25.56669)
# 90165  POINT (91.90835 25.58906)
# 47447  POINT (91.91681 25.57166)
# 80405  POINT (91.89495 25.58332)
# 35259  POINT (91.89869 25.56644)

# %% [markdown]
# ### Save sampled data (original rooftop pins)

# %%
save_shapefiles(
    sampled_rooftops_organised_gdf,
    OUTPUT_DATA_DIR / "01. Sampled Rooftop Data",
    "sampled_rooftops_centroids_original",
    ["csv", "parquet", "kml"],
)
# Out:
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Lossy conversion occurred when trying to set 64 bit integer field from a real value.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.558151558092337,91.88286705691951' of field sampled_rooftops_centroids_original.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.557829436782477,91.91444625907221' of field sampled_rooftops_centroids_original.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.570808473743693,91.89839986142023' of field sampled_rooftops_centroids_original.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.5767549272813,91.91746469064805' of field sampled_rooftops_centroids_original.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.58424863258701,91.89834060704894' of field sampled_rooftops_centroids_original.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.58419085345247,91.9014791709791' of field sampled_rooftops_centroids_original.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.589357095704553,91.9113497435598' of field sampled_rooftops_centroids_original.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.565261424223152,91.87898548414256' of field sampled_rooftops_centroids_original.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.569767586696802,91.90632817282514' of field sampled_rooftops_centroids_original.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.583297830853557,91.87151384200364' of field sampled_rooftops_centroids_original.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.587866487782915,91.91033146660855' of field sampled_rooftops_centroids_original.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.570023168405907,91.90979176610658' of field sampled_rooftops_centroids_original.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.568867298948394,91.88624197224642' of field sampled_rooftops_centroids_original.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.572990786407075,91.92024521425489' of field sampled_rooftops_centroids_original.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.575288738977026,91.91278860577032' of field sampled_rooftops_centroids_original.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.59287802838715,91.86966203448021' of field sampled_rooftops_centroids_original.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.57169342435105,91.9217289426886' of field sampled_rooftops_centroids_original.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.594492717642098,91.86755389578508' of field sampled_rooftops_centroids_original.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.555262304993715,91.91557374746185' of field sampled_rooftops_centroids_original.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.582435434633705,91.92156191085795' of field sampled_rooftops_centroids_original.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.58950772182487,91.92112939100512' of field sampled_rooftops_centroids_original.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.59355220214848,91.88093000782719' of field sampled_rooftops_centroids_original.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.57622068129501,91.85234626530455' of field sampled_rooftops_centroids_original.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.584634301285195,91.88247082517645' of field sampled_rooftops_centroids_original.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.59176173719478,91.91485032596471' of field sampled_rooftops_centroids_original.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.566689354075752,91.84502781939814' of field sampled_rooftops_centroids_original.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.589063786027296,91.90835287769646' of field sampled_rooftops_centroids_original.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.571655058109425,91.91680601173643' of field sampled_rooftops_centroids_original.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.583322735137557,91.89495238528127' of field sampled_rooftops_centroids_original.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.566440684605062,91.89868883691356' of field sampled_rooftops_centroids_original.latitude parsed incompletely to real 0.
#   ogr_write(

# %% [markdown]
# ## 9. Snap points to road

# %% [markdown]
# ### Functions

# %%
from shapely import Point
import requests
from concurrent.futures import ThreadPoolExecutor


def get_nearest_point_on_road(point: Point, api_key: str) -> Point | None:
    """
    Retrieves the nearest point on the road for a given point using the Google Roads API.

    Args:
        point (Point): The point for which to find the nearest point on the road.
        api_key (str): Your Google Roads API key.

    Returns:
        Point: The nearest point on the road, or None if no point is found.

    """
    url = f"https://roads.googleapis.com/v1/snapToRoads?path={point.y},{point.x}&key={api_key}"
    response = requests.get(url)
    snapped_point = response.json().get("snappedPoints", [{}])[0].get("location")
    return (
        Point(snapped_point["longitude"], snapped_point["latitude"])
        if snapped_point
        else None
    )

def snap_point_to_road(args):
    """Helper function to snap a point to the nearest road."""
    idx, point, api_key = args
    try:
        snapped_point = get_nearest_point_on_road(point, api_key)
        return idx, snapped_point
    except Exception as e:
        print(f"Error snapping point at index {idx}: {str(e)}")
        return idx, None

def snap_points_to_roads_parallel(gdf, api_key, max_workers=10) -> gpd.GeoSeries:
    """
    Snap all points in a GeoDataFrame to the nearest road using parallel processing.
    
    Args:
        gdf: GeoDataFrame containing point geometries
        api_key: Google Roads API key
        max_workers: Number of parallel workers
        
    Returns:
        GeoSeries with snapped geometries
    """
    # Prepare arguments for parallel processing
    args_list = [(idx, point, api_key) for idx, point in enumerate(gdf.geometry)]
    
    # Initialize results dictionary
    snapped_points = {}
    
    # Process in parallel with progress bar
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        # Submit all tasks and track with tqdm
        results = list(tqdm(
            executor.map(snap_point_to_road, args_list), 
            total=len(args_list),
            desc="Snapping points to roads"
        ))
    
    # Process results
    for idx, snapped_point in results:
        snapped_points[idx] = snapped_point
    snapped_points_series = gpd.GeoSeries(snapped_points)

    return snapped_points_series

# %% [markdown]
# ### Run

# %%
# load API key
import yaml
with open('../secrets/api_keys.yaml', 'r') as f:
    config = yaml.safe_load(f)
    api_key = config['GOOGLE_ROADS_API_KEY']

# %%
# test
get_nearest_point_on_road(
    sampled_rooftops_organised_gdf.geometry.iloc[0], api_key
)
# Out:
# <POINT (91.883 25.558)>

# %%
len(sampled_rooftops_organised_gdf)
# Out:
# 30

# %% [markdown]
# #### Snap points to road

# %%
snapped_points_series = snap_points_to_roads_parallel(
    sampled_rooftops_organised_gdf, 
    api_key,
    max_workers=12
)
# took 1min for 3,200 points
# Out:
# Snapping points to roads:   0%|          | 0/30 [00:00<?, ?it/s]

# %%
sampled_rooftops_snapped_gdf = sampled_rooftops_organised_gdf.copy()
sampled_rooftops_snapped_gdf["geometry_snapped"] = list(snapped_points_series)

# %%
# Make new Geometry Type column which has values "Original" or "Snapped to Road"
sampled_rooftops_snapped_gdf["Geometry Type"] = (
    sampled_rooftops_snapped_gdf["geometry_snapped"]
    .notna()
    .replace({True: "Snapped to Road", False: "Original"})
)
sampled_rooftops_snapped_gdf["Geometry Type"].value_counts()
# Out:
# Geometry Type
# Snapped to Road    30
# Name: count, dtype: int64

# %% [markdown]
# #### Replace geometry to snapped one (missing filled in with original)

# %%
# backup the original geometry
sampled_rooftops_snapped_gdf["geometry_original"] = sampled_rooftops_snapped_gdf[
    "geometry"
]
# replace the original geometry with the snapped geometry
sampled_rooftops_snapped_gdf["geometry"] = sampled_rooftops_snapped_gdf[
    "geometry_snapped"
]
# drop the snapped geometry column
sampled_rooftops_snapped_gdf = sampled_rooftops_snapped_gdf.drop(
    columns=["geometry_snapped"]
)
# fill in NaN values in the snapped geometry with the original geometry
sampled_rooftops_snapped_gdf.loc[
    sampled_rooftops_snapped_gdf["geometry"].isna(), 
    "geometry"] = sampled_rooftops_snapped_gdf.loc[
        sampled_rooftops_snapped_gdf["geometry"].isna(),
        "geometry_original"
]

# %%
sampled_rooftops_snapped_gdf["geometry"].isna().sum()
# Out:
# 0

# %% [markdown]
# #### Update lat, lon, gmap_link

# %%
sampled_rooftops_snapped_gdf = sampled_rooftops_snapped_gdf.rename(
    columns={
        "latitude": "latitude_original",
        "longitude": "longitude_original",
        "gmap_link": "gmap_link_original",
    },
)

# %%
sampled_rooftops_snapped_gdf["latitude"] = list(
    sampled_rooftops_snapped_gdf.geometry.y
)
sampled_rooftops_snapped_gdf["longitude"] = list(
    sampled_rooftops_snapped_gdf.geometry.x
)
sampled_rooftops_snapped_gdf["gmap_link"] = create_gmap_links(
    df=sampled_rooftops_snapped_gdf,
    lat_name="latitude",
    lon_name="longitude",
)

# %% [markdown]
# #### Reorganise

# %%
sampled_rooftops_snapped_gdf.columns
# Out:
# Index(['Unique Rooftop ID', 'Unique Shape ID', 'Rooftop ID Per Shape',
#        'latitude_original', 'longitude_original', 'gmap_link_original',
#        'geometry', 'Geometry Type', 'geometry_original', 'latitude',
#        'longitude', 'gmap_link'],
#       dtype='object')

# %%
sampled_rooftops_snapped_gdf = sampled_rooftops_snapped_gdf[
    [
        "Unique Rooftop ID",
        "Unique Shape ID",
        "Rooftop ID Per Shape",
        "Geometry Type",
        "latitude",
        "longitude",
        "gmap_link",
        "latitude_original",
        "longitude_original",
        "gmap_link_original",
        "geometry_original",
        "geometry",
    ]
]

# %% [markdown]
# #### Make lines between original and snapped points

# %%
from shapely.geometry import LineString

# %%
sampled_rooftops_snapped_gdf["geometry_line"] = sampled_rooftops_snapped_gdf.apply(
    lambda row: LineString([row["geometry_original"], row["geometry"]]), axis=1
)

# %%
sampled_rooftops_snapped_gdf["geometry_line"].isna().sum()
# Out:
# 0

# %% [markdown]
# #### Save new files: snapped points, snapped lines

# %%
# Save snapped points
save_shapefiles(
    sampled_rooftops_snapped_gdf.drop(
        columns=[
            "geometry_original",
            "geometry_line",
        ]
    ),
    OUTPUT_DATA_DIR / "01. Sampled Rooftop Data",
    "sampled_rooftops_snapped_points",
    ["csv", "parquet", "kml"],
)
# Out:
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Lossy conversion occurred when trying to set 64 bit integer field from a real value.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.55805173578541,91.88291580289892' of field sampled_rooftops_snapped_points.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.558151558092337,91.88286705691951' of field sampled_rooftops_snapped_points.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.557714899999997,91.9147145' of field sampled_rooftops_snapped_points.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.557829436782477,91.91444625907221' of field sampled_rooftops_snapped_points.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.57086116762265,91.89833279238474' of field sampled_rooftops_snapped_points.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.570808473743693,91.89839986142023' of field sampled_rooftops_snapped_points.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.576761221337943,91.91750755502517' of field sampled_rooftops_snapped_points.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.5767549272813,91.91746469064805' of field sampled_rooftops_snapped_points.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.5841286,91.89850609999999' of field sampled_rooftops_snapped_points.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.58424863258701,91.89834060704894' of field sampled_rooftops_snapped_points.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.5843422,91.9014885' of field sampled_rooftops_snapped_points.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.58419085345247,91.9014791709791' of field sampled_rooftops_snapped_points.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.58938382613029,91.91127139124846' of field sampled_rooftops_snapped_points.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.589357095704553,91.9113497435598' of field sampled_rooftops_snapped_points.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.56522100953181,91.87887104853378' of field sampled_rooftops_snapped_points.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.565261424223152,91.87898548414256' of field sampled_rooftops_snapped_points.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.569883299999994,91.90661639999999' of field sampled_rooftops_snapped_points.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.569767586696802,91.90632817282514' of field sampled_rooftops_snapped_points.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.58325847764966,91.87159012745788' of field sampled_rooftops_snapped_points.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.583297830853557,91.87151384200364' of field sampled_rooftops_snapped_points.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.587909235615275,91.91033838810328' of field sampled_rooftops_snapped_points.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.587866487782915,91.91033146660855' of field sampled_rooftops_snapped_points.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.570117493628878,91.90997401079436' of field sampled_rooftops_snapped_points.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.570023168405907,91.90979176610658' of field sampled_rooftops_snapped_points.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.568735834339375,91.88631721825357' of field sampled_rooftops_snapped_points.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.568867298948394,91.88624197224642' of field sampled_rooftops_snapped_points.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.573083005235826,91.92022551427377' of field sampled_rooftops_snapped_points.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.572990786407075,91.92024521425489' of field sampled_rooftops_snapped_points.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.575524699999995,91.912713' of field sampled_rooftops_snapped_points.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.575288738977026,91.91278860577032' of field sampled_rooftops_snapped_points.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.592843812383606,91.86969311644452' of field sampled_rooftops_snapped_points.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.59287802838715,91.86966203448021' of field sampled_rooftops_snapped_points.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.571692231680775,91.92192630928291' of field sampled_rooftops_snapped_points.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.57169342435105,91.9217289426886' of field sampled_rooftops_snapped_points.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.5944052,91.8674216' of field sampled_rooftops_snapped_points.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.594492717642098,91.86755389578508' of field sampled_rooftops_snapped_points.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.555322,91.9155693' of field sampled_rooftops_snapped_points.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.555262304993715,91.91557374746185' of field sampled_rooftops_snapped_points.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.582245202921094,91.92165744184864' of field sampled_rooftops_snapped_points.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.582435434633705,91.92156191085795' of field sampled_rooftops_snapped_points.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.589548405119107,91.921219886147' of field sampled_rooftops_snapped_points.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.58950772182487,91.92112939100512' of field sampled_rooftops_snapped_points.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.59356626706002,91.88095720793082' of field sampled_rooftops_snapped_points.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.59355220214848,91.88093000782719' of field sampled_rooftops_snapped_points.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.5761273694919,91.85234350877076' of field sampled_rooftops_snapped_points.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.57622068129501,91.85234626530455' of field sampled_rooftops_snapped_points.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.5845468,91.88224509999999' of field sampled_rooftops_snapped_points.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.584634301285195,91.88247082517645' of field sampled_rooftops_snapped_points.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.591726034505292,91.91477156379757' of field sampled_rooftops_snapped_points.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.59176173719478,91.91485032596471' of field sampled_rooftops_snapped_points.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.56666855868738,91.84512081334407' of field sampled_rooftops_snapped_points.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.566689354075752,91.84502781939814' of field sampled_rooftops_snapped_points.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.58907245635711,91.908293781274' of field sampled_rooftops_snapped_points.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.589063786027296,91.90835287769646' of field sampled_rooftops_snapped_points.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.571776254287563,91.91694329923101' of field sampled_rooftops_snapped_points.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.571655058109425,91.91680601173643' of field sampled_rooftops_snapped_points.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.583354648880864,91.89487267545083' of field sampled_rooftops_snapped_points.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.583322735137557,91.89495238528127' of field sampled_rooftops_snapped_points.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.566445599999994,91.89876369999999' of field sampled_rooftops_snapped_points.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.566440684605062,91.89868883691356' of field sampled_rooftops_snapped_points.latitude_original parsed incompletely to real 0.
#   ogr_write(

# %%
# Save lines
sampled_rooftops_line_gdf = sampled_rooftops_snapped_gdf.copy()
sampled_rooftops_line_gdf["geometry"] = sampled_rooftops_line_gdf["geometry_line"]
save_shapefiles(
    sampled_rooftops_line_gdf.drop(
    columns=["geometry_line", "geometry_original"]
),
    OUTPUT_DATA_DIR / "01. Sampled Rooftop Data",
    "sampled_rooftops_snapped_lines",
    ["csv", "parquet", "kml"],
)
# Out:
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Lossy conversion occurred when trying to set 64 bit integer field from a real value.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.55805173578541,91.88291580289892' of field sampled_rooftops_snapped_lines.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.558151558092337,91.88286705691951' of field sampled_rooftops_snapped_lines.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.557714899999997,91.9147145' of field sampled_rooftops_snapped_lines.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.557829436782477,91.91444625907221' of field sampled_rooftops_snapped_lines.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.57086116762265,91.89833279238474' of field sampled_rooftops_snapped_lines.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.570808473743693,91.89839986142023' of field sampled_rooftops_snapped_lines.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.576761221337943,91.91750755502517' of field sampled_rooftops_snapped_lines.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.5767549272813,91.91746469064805' of field sampled_rooftops_snapped_lines.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.5841286,91.89850609999999' of field sampled_rooftops_snapped_lines.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.58424863258701,91.89834060704894' of field sampled_rooftops_snapped_lines.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.5843422,91.9014885' of field sampled_rooftops_snapped_lines.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.58419085345247,91.9014791709791' of field sampled_rooftops_snapped_lines.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.58938382613029,91.91127139124846' of field sampled_rooftops_snapped_lines.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.589357095704553,91.9113497435598' of field sampled_rooftops_snapped_lines.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.56522100953181,91.87887104853378' of field sampled_rooftops_snapped_lines.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.565261424223152,91.87898548414256' of field sampled_rooftops_snapped_lines.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.569883299999994,91.90661639999999' of field sampled_rooftops_snapped_lines.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.569767586696802,91.90632817282514' of field sampled_rooftops_snapped_lines.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.58325847764966,91.87159012745788' of field sampled_rooftops_snapped_lines.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.583297830853557,91.87151384200364' of field sampled_rooftops_snapped_lines.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.587909235615275,91.91033838810328' of field sampled_rooftops_snapped_lines.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.587866487782915,91.91033146660855' of field sampled_rooftops_snapped_lines.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.570117493628878,91.90997401079436' of field sampled_rooftops_snapped_lines.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.570023168405907,91.90979176610658' of field sampled_rooftops_snapped_lines.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.568735834339375,91.88631721825357' of field sampled_rooftops_snapped_lines.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.568867298948394,91.88624197224642' of field sampled_rooftops_snapped_lines.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.573083005235826,91.92022551427377' of field sampled_rooftops_snapped_lines.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.572990786407075,91.92024521425489' of field sampled_rooftops_snapped_lines.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.575524699999995,91.912713' of field sampled_rooftops_snapped_lines.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.575288738977026,91.91278860577032' of field sampled_rooftops_snapped_lines.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.592843812383606,91.86969311644452' of field sampled_rooftops_snapped_lines.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.59287802838715,91.86966203448021' of field sampled_rooftops_snapped_lines.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.571692231680775,91.92192630928291' of field sampled_rooftops_snapped_lines.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.57169342435105,91.9217289426886' of field sampled_rooftops_snapped_lines.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.5944052,91.8674216' of field sampled_rooftops_snapped_lines.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.594492717642098,91.86755389578508' of field sampled_rooftops_snapped_lines.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.555322,91.9155693' of field sampled_rooftops_snapped_lines.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.555262304993715,91.91557374746185' of field sampled_rooftops_snapped_lines.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.582245202921094,91.92165744184864' of field sampled_rooftops_snapped_lines.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.582435434633705,91.92156191085795' of field sampled_rooftops_snapped_lines.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.589548405119107,91.921219886147' of field sampled_rooftops_snapped_lines.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.58950772182487,91.92112939100512' of field sampled_rooftops_snapped_lines.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.59356626706002,91.88095720793082' of field sampled_rooftops_snapped_lines.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.59355220214848,91.88093000782719' of field sampled_rooftops_snapped_lines.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.5761273694919,91.85234350877076' of field sampled_rooftops_snapped_lines.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.57622068129501,91.85234626530455' of field sampled_rooftops_snapped_lines.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.5845468,91.88224509999999' of field sampled_rooftops_snapped_lines.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.584634301285195,91.88247082517645' of field sampled_rooftops_snapped_lines.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.591726034505292,91.91477156379757' of field sampled_rooftops_snapped_lines.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.59176173719478,91.91485032596471' of field sampled_rooftops_snapped_lines.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.56666855868738,91.84512081334407' of field sampled_rooftops_snapped_lines.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.566689354075752,91.84502781939814' of field sampled_rooftops_snapped_lines.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.58907245635711,91.908293781274' of field sampled_rooftops_snapped_lines.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.589063786027296,91.90835287769646' of field sampled_rooftops_snapped_lines.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.571776254287563,91.91694329923101' of field sampled_rooftops_snapped_lines.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.571655058109425,91.91680601173643' of field sampled_rooftops_snapped_lines.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.583354648880864,91.89487267545083' of field sampled_rooftops_snapped_lines.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.583322735137557,91.89495238528127' of field sampled_rooftops_snapped_lines.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.566445599999994,91.89876369999999' of field sampled_rooftops_snapped_lines.latitude parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'https://www.google.com/maps/search/?api=1&query=25.566440684605062,91.89868883691356' of field sampled_rooftops_snapped_lines.latitude_original parsed incompletely to real 0.
#   ogr_write(
