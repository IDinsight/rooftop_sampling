# %% [markdown]
# ## 0. Setup

# %%
# set libraries to refresh
# %load_ext autoreload
# %autoreload 2

# %%
# general
from pathlib import Path

import geopandas as gpd

# for plotting and coloring
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from matplotlib.colors import ListedColormap
from tqdm.notebook import tqdm

gpd.options.io_engine = "pyogrio"

# %%
from gridsample.utils import create_gmap_links, save_shapefiles
# from gridsample.mapping import create_interactive_map

# %%
from utils import (
    download_VIDA_rooftops_data_by_s2,
    generate_colormap,
    get_matched_rooftop_centroids_from_s2_file,
    get_s2_cell_ids,
    s2_cell_ids_to_shapes_gdf,
)

# %%
ROOT_DIR = Path("../")
DATA_DIR = ROOT_DIR / "data_panel"
RAW_DATA_DIR = DATA_DIR / "01. Raw Data" #symlinked from IFS folder
CLEANED_DATA_DIR = DATA_DIR / "02. Intermediate Outputs" / "replacements_v2_mumbai_replacements"
OUTPUT_DATA_DIR = DATA_DIR / "03. Final Outputs" / "replacements_v2_mumbai_replacements"
OUTPUT_DATA_DIR.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## 1. Load MapSolve boundaries

# %%
# get all filepaths that end in `gpkg` inside the RAW_DATA_DIR / 0.1. MapSolve Boundaries
boundaries_dir = RAW_DATA_DIR / "01. MapSolve Boundaries"
gpkg_files_all = list(boundaries_dir.glob("**/*.gpkg"))
gpkg_files_all = [f for f in gpkg_files_all if f.is_file()]
# # drop any with the word "Sub-District" in the filename
# gpkg_files_VTW = [f for f in gpkg_files_all if "Sub-District" not in f.name]
# load all shapes into one gdf
gdf_list = []
for filepath in gpkg_files_all:
    gdf_list.append(gpd.read_file(filepath))
gdf = pd.concat(gdf_list, ignore_index=True).to_crs(4326)

# %%
gdf = gdf.drop_duplicates()

# %% [markdown]
# ### Fix ad-hoc issues (see quality check notebook)

# %%
# chittoor
gdf.loc[gdf["TV_C"] == 803014, ["SubDist_N", "SubDist_C"]] = ["Tirupati (Urban)", 5383]
# patna
gdf.loc[(gdf["TV_C"] == 801373) & (gdf["Ward_C"] == "3"), "PCA_ID"] = "801373-3"
# MDDS codes
gdf.loc[gdf["TV_C"] == 519923, ["TV_C", "Ward_C", "PCA_ID"]] = [802596, 18, "802596-18"]
gdf.loc[gdf["TV_C"] == 574077, ["TV_C", "Ward_C", "PCA_ID"]] = [802918, 157, "802918-157"]

# %%
gdf.plot(column="State_N", legend=True, figsize=(10, 10), cmap="tab20")
# Out:
# <Axes: >

# %% [markdown]
# ## 2. Load sampled wards data

# %%
# load the merged wards data
sample_df = pd.read_csv(
    CLEANED_DATA_DIR
    / "00. Merge and Quality Checks"
    / "Panel Wards with Quality Checks.csv"
)

# %% [markdown]
# ### 2.1 Rename and clean both datasets

# %%
rename_dict = {
    "UID": "UID",
    "PCA_ID": "PCA_ID",
    "State_C": "State Code",
    "State_N": "State Name",
    "Dist_C": "District Code",
    "Dist_N": "District Name",
    "SubDist_C": "Subdistrict Code",
    "SubDist_N": "Subdistrict Name",
    "TV_C": "TV Code",
    "TV_N": "TV Name",
    "Ward_C": "Ward Code",
    "TOT_P": "Total Population",
}

gdf = gdf.rename(columns=rename_dict)

# %%
rename_dict = {
    "State": "State Code",
    "State_Name": "State Name",
    "District": "District Code",
    "District_Name": "District Name",
    "Subdistrict": "Subdistrict Code",
    "Subd_Name": "Subdistrict Name",
    "TownVillage": "TV Code",
    "UrbanWardVillage": "Ward Code",
    "WardVillage_Name": "Ward/Village Name",
    "TRU": "Urban/Rural",
    "WardVillage_Pop": "Ward Population",
    "Subd_Pop": "Subdistrict Population",
    "State_Pop": "State Population",
    "WardVillageID": "Complete ID",
}
sample_df = sample_df.rename(columns=rename_dict)

# make State Name heading case instead of all caps
sample_df["State Name"] = sample_df["State Name"].str.title()
sample_df.loc[sample_df["State Name"] == "Nct Of Delhi", "State Name"] = "NCT of Delhi"

# %%
# make relevant codes into floats for both datasets
code_columns = [
    "State Code",
    "District Code",
    "Subdistrict Code",
    "TV Code",
    "Ward Code",
]
for col in code_columns:
    sample_df[col] = sample_df[col].astype(float)
    gdf[col] = gdf[col].astype(float)

# %% [markdown]
# ## 3. Filter MapSolve boundaries to sampled areas

# %% [markdown]
# ### 3.2 Drop unnecessary rows

# %% [markdown]
# #### Drop rows with no MapSolve shapes

# %%
sample_df[sample_df["PSU Type"] == "none"]
# Out:
# Empty DataFrame
# Columns: [State Code, State Name, District Code, District Name, Subdistrict Code, Subdistrict Name, TV Code, Ward Code, Ward/Village Name, PCA_ID, Urban/Rural, Ward Population, Subdistrict Population, State Population, Complete ID, Ward Boundary Available with MapSolve, State Shared by MapSolve, State Changed, Ward Boundary Given, TV Boundary Given, SubDistrict Boundary Given, Delivery State, PSU Type, PSU ID, Ward Count]
# Index: []
#
# [0 rows x 25 columns]

# %%
filtered_df = sample_df[sample_df["PSU Type"] != "none"]

# %%
filtered_df
# Out:
#     State Code   State Name  District Code    District Name  Subdistrict Code  \
# 0         27.0  Maharashtra          518.0  Mumbai Suburban           99999.0
# 1         27.0  Maharashtra          518.0  Mumbai Suburban           99999.0
# 2         27.0  Maharashtra          518.0  Mumbai Suburban           99999.0
# 3         27.0  Maharashtra          518.0  Mumbai Suburban           99999.0
# 4         27.0  Maharashtra          518.0  Mumbai Suburban           99999.0
# 5         27.0  Maharashtra          518.0  Mumbai Suburban           99999.0
# 6         27.0  Maharashtra          518.0  Mumbai Suburban           99999.0
# 7         27.0  Maharashtra          518.0  Mumbai Suburban           99999.0
# 8         27.0  Maharashtra          518.0  Mumbai Suburban           99999.0
# 9         27.0  Maharashtra          518.0  Mumbai Suburban           99999.0
# 10        27.0  Maharashtra          518.0  Mumbai Suburban           99999.0
# 11        27.0  Maharashtra          518.0  Mumbai Suburban           99999.0
# 12        27.0  Maharashtra          518.0  Mumbai Suburban           99999.0
#
#                    Subdistrict Name   TV Code  Ward Code  \
# 0   Area not under any Sub-district  802794.0     1043.0
# 1   Area not under any Sub-district  802794.0     1144.0
# 2   Area not under any Sub-district  802794.0     1249.0
# 3   Area not under any Sub-district  802794.0     1255.0
# 4   Area not under any Sub-district  802794.0     1256.0
# 5   Area not under any Sub-district  802794.0     1354.0
# 6   Area not under any Sub-district  802794.0     1357.0
# 7   Area not under any Sub-district  802794.0     1458.0
# 8   Area not under any Sub-district  802794.0     1459.0
# 9   Area not under any Sub-district  802794.0     1562.0
# 10  Area not under any Sub-district  802794.0     1978.0
# 11  Area not under any Sub-district  802794.0     2080.0
# 12  Area not under any Sub-district  802794.0     2179.0
#
#                                 Ward/Village Name       PCA_ID  ...  \
# 0   Greater Mumbai (M Corp.) (Part) WARD NO.-1043  802794-1043  ...
# 1   Greater Mumbai (M Corp.) (Part) WARD NO.-1144  802794-1144  ...
# 2   Greater Mumbai (M Corp.) (Part) WARD NO.-1249  802794-1249  ...
# 3   Greater Mumbai (M Corp.) (Part) WARD NO.-1255  802794-1255  ...
# 4   Greater Mumbai (M Corp.) (Part) WARD NO.-1256  802794-1256  ...
# 5   Greater Mumbai (M Corp.) (Part) WARD NO.-1354  802794-1354  ...
# 6   Greater Mumbai (M Corp.) (Part) WARD NO.-1357  802794-1357  ...
# 7   Greater Mumbai (M Corp.) (Part) WARD NO.-1458  802794-1458  ...
# 8   Greater Mumbai (M Corp.) (Part) WARD NO.-1459  802794-1459  ...
# 9   Greater Mumbai (M Corp.) (Part) WARD NO.-1562  802794-1562  ...
# 10  Greater Mumbai (M Corp.) (Part) WARD NO.-1978  802794-1978  ...
# 11  Greater Mumbai (M Corp.) (Part) WARD NO.-2080  802794-2080  ...
# 12  Greater Mumbai (M Corp.) (Part) WARD NO.-2179  802794-2179  ...
#
#    Ward Boundary Available with MapSolve  State Shared by MapSolve  \
# 0                                    Yes                      True
# 1                                    Yes                      True
# 2                                    Yes                      True
# 3                                    Yes                      True
# 4                                    Yes                      True
# 5                                    Yes                      True
# 6                                    Yes                      True
# 7                                    Yes                      True
# 8                                    Yes                      True
# 9                                    Yes                      True
# 10                                   Yes                      True
# 11                                   Yes                      True
# 12                                   Yes                      True
#
#     State Changed  Ward Boundary Given TV Boundary Given  \
# 0              No                 True             False
# 1              No                 True             False
# 2              No                 True             False
# 3              No                 True             False
# 4              No                 True             False
# 5              No                 True             False
# 6              No                 True             False
# 7              No                 True             False
# 8              No                 True             False
# 9              No                 True             False
# 10             No                 True             False
# 11             No                 True             False
# 12             No                 True             False
#
#    SubDistrict Boundary Given                          Delivery State  \
# 0                       False  GOOD - Ward boundary given as expected
# 1                       False  GOOD - Ward boundary given as expected
# 2                       False  GOOD - Ward boundary given as expected
# 3                       False  GOOD - Ward boundary given as expected
# 4                       False  GOOD - Ward boundary given as expected
# 5                       False  GOOD - Ward boundary given as expected
# 6                       False  GOOD - Ward boundary given as expected
# 7                       False  GOOD - Ward boundary given as expected
# 8                       False  GOOD - Ward boundary given as expected
# 9                       False  GOOD - Ward boundary given as expected
# 10                      False  GOOD - Ward boundary given as expected
# 11                      False  GOOD - Ward boundary given as expected
# 12                      False  GOOD - Ward boundary given as expected
#
#    PSU Type            PSU ID  Ward Count
# 0      ward  WARD_802794-1043           1
# 1      ward  WARD_802794-1144           1
# 2      ward  WARD_802794-1249           1
# 3      ward  WARD_802794-1255           1
# 4      ward  WARD_802794-1256           1
# 5      ward  WARD_802794-1354           1
# 6      ward  WARD_802794-1357           1
# 7      ward  WARD_802794-1458           1
# 8      ward  WARD_802794-1459           1
# 9      ward  WARD_802794-1562           1
# 10     ward  WARD_802794-1978           1
# 11     ward  WARD_802794-2080           1
# 12     ward  WARD_802794-2179           1
#
# [13 rows x 25 columns]

# %%
# check bad rows, leave as is though
filtered_df[filtered_df["Delivery State"].str.contains("BAD")]
# Out:
# Empty DataFrame
# Columns: [State Code, State Name, District Code, District Name, Subdistrict Code, Subdistrict Name, TV Code, Ward Code, Ward/Village Name, PCA_ID, Urban/Rural, Ward Population, Subdistrict Population, State Population, Complete ID, Ward Boundary Available with MapSolve, State Shared by MapSolve, State Changed, Ward Boundary Given, TV Boundary Given, SubDistrict Boundary Given, Delivery State, PSU Type, PSU ID, Ward Count]
# Index: []
#
# [0 rows x 25 columns]

# %% [markdown]
# #### Duplicated wards

# %%
filtered_df[filtered_df["PCA_ID"].duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [State Code, State Name, District Code, District Name, Subdistrict Code, Subdistrict Name, TV Code, Ward Code, Ward/Village Name, PCA_ID, Urban/Rural, Ward Population, Subdistrict Population, State Population, Complete ID, Ward Boundary Available with MapSolve, State Shared by MapSolve, State Changed, Ward Boundary Given, TV Boundary Given, SubDistrict Boundary Given, Delivery State, PSU Type, PSU ID, Ward Count]
# Index: []
#
# [0 rows x 25 columns]

# %%
print(f"Number of rows before dropping PCA_ID duplicates: {len(filtered_df)}")
print(
    f"Number of rows after dropping PCA_ID duplicates: {len(filtered_df.drop_duplicates(subset=['PCA_ID'], keep='first'))}"
)
# Out:
# Number of rows before dropping PCA_ID duplicates: 13
# Number of rows after dropping PCA_ID duplicates: 13

# %%
filtered_df = filtered_df.drop_duplicates(subset=["PCA_ID"], keep="first")

# %% [markdown]
# #### Check for duplicated `PSU ID`

# %%
filtered_df[filtered_df.duplicated(subset=["PSU ID"], keep=False)]
# Out:
# Empty DataFrame
# Columns: [State Code, State Name, District Code, District Name, Subdistrict Code, Subdistrict Name, TV Code, Ward Code, Ward/Village Name, PCA_ID, Urban/Rural, Ward Population, Subdistrict Population, State Population, Complete ID, Ward Boundary Available with MapSolve, State Shared by MapSolve, State Changed, Ward Boundary Given, TV Boundary Given, SubDistrict Boundary Given, Delivery State, PSU Type, PSU ID, Ward Count]
# Index: []
#
# [0 rows x 25 columns]

# %%
filtered_df = filtered_df.drop_duplicates(subset=["PSU ID"], keep="first")
len(filtered_df) == filtered_df["PSU ID"].nunique()
# Out:
# True

# %% [markdown]
# ## 4. Merge shapes at the respective PSU level

# %% [markdown]
# ### Wards

# %%
# PCA IDs to match (TVCode-WardCode)
pca_ids_to_match = filtered_df.loc[filtered_df["PSU Type"] == "ward", "PCA_ID"].unique()
len(pca_ids_to_match)
# Out:
# 13

# %%
wards_gdf = gpd.GeoDataFrame(
    filtered_df[filtered_df["PSU Type"] == "ward"].merge(
        gdf[gdf["PCA_ID"].isin(pca_ids_to_match)],
        on=["PCA_ID"],
        how="left",
        suffixes=("", "_MapSolve"),
    ),
    geometry="geometry",
)
wards_gdf.shape
# Out:
# (13, 37)

# %% [markdown]
# ### Town/Village

# %%
# # TV codes to match
# tv_codes_to_match = filtered_df.loc[
#     filtered_df["PSU Type"] == "town_village", "TV Code"
# ].unique()
# len(tv_codes_to_match)

# %%
# tv_gdf = gpd.GeoDataFrame(
#     filtered_df[filtered_df["PSU Type"] == "town_village"].merge(
#         gdf[gdf["TV Code"].isin(tv_codes_to_match) & gdf["Ward Code"].isna()],
#         on=["TV Code"],
#         how="left",
#         suffixes=("", "_MapSolve"),
#     )
# )
# tv_gdf.shape

# %%
# # cut out the ward geometries from the TV geometries so we don't double sample those areas
# trimmed_tv_geoms = tv_gdf.difference(wards_gdf.geometry.unary_union)
# trimmed_tv_gdf = gpd.GeoDataFrame(
#     tv_gdf.drop(columns="geometry").assign(geometry=trimmed_tv_geoms),
#     crs=tv_gdf.crs,
# )

# %% [markdown]
# ### Subdistrict

# %%
# # subdistrict codes to match
# subdistrict_codes_to_match = filtered_df.loc[
#     filtered_df["PSU Type"] == "subdistrict", "Subdistrict Code"
# ].unique()
# len(subdistrict_codes_to_match)

# %%
# subdistrict_gdf = gpd.GeoDataFrame(
#     filtered_df[filtered_df["PSU Type"] == "subdistrict"].merge(
#         gdf[
#             gdf["Subdistrict Code"].isin(subdistrict_codes_to_match)
#             & (gdf["TV Code"].isna())
#             & (gdf["Ward Code"].isna())
#         ],
#         on=["Subdistrict Code"],
#         how="left",
#         suffixes=("", "_MapSolve"),
#     )
# )

# %%
# # cut out the TV and Ward geometries from the subdistrict geometries so we don't double sample those areas
# combined_tv_and_ward_union_shape = wards_gdf.geometry.unary_union.union(
#     trimmed_tv_gdf.geometry.unary_union
# )
# trimmed_subdistrict_geoms = subdistrict_gdf.difference(combined_tv_and_ward_union_shape)
# trimmed_subdistrict_gdf = gpd.GeoDataFrame(
#     subdistrict_gdf.drop(columns="geometry").assign(geometry=trimmed_subdistrict_geoms),
#     crs=subdistrict_gdf.crs,
# )

# %% [markdown]
# ### Combine

# %%
# combine all three GeoDataFrames into one
combined_gdf = gpd.GeoDataFrame(
    pd.concat(
        [
            wards_gdf,
            # trimmed_tv_gdf,
            # trimmed_subdistrict_gdf,
        ],
        ignore_index=True,
    )
)
combined_gdf = combined_gdf.sort_values(
    by=["State Code", "District Code", "Subdistrict Code", "TV Code", "Ward Code"]
).reset_index(drop=True)

# %%
combined_gdf.plot(column="State Name")
# Out:
# <Axes: >

# %% [markdown]
# ### Drop rows duplicated `PSU ID` (could happen)

# %%
duplicated_psu_id_gdf = combined_gdf[combined_gdf.duplicated(subset=["PSU ID"], keep=False)]
duplicated_psu_id_gdf
# Out:
# Empty GeoDataFrame
# Columns: [State Code, State Name, District Code, District Name, Subdistrict Code, Subdistrict Name, TV Code, Ward Code, Ward/Village Name, PCA_ID, Urban/Rural, Ward Population, Subdistrict Population, State Population, Complete ID, Ward Boundary Available with MapSolve, State Shared by MapSolve, State Changed, Ward Boundary Given, TV Boundary Given, SubDistrict Boundary Given, Delivery State, PSU Type, PSU ID, Ward Count, UID, State Code_MapSolve, State Name_MapSolve, District Code_MapSolve, District Name_MapSolve, Subdistrict Code_MapSolve, Subdistrict Name_MapSolve, TV Code_MapSolve, TV Name, Ward Code_MapSolve, Total Population, geometry]
# Index: []
#
# [0 rows x 37 columns]

# %%
duplicated_psu_id_gdf.groupby("PSU ID").plot(alpha=0.5, column="PSU ID", legend=True)
# Out:
# Empty GeoDataFrame
# Columns: [State Code, State Name, District Code, District Name, Subdistrict Code, Subdistrict Name, TV Code, Ward Code, Ward/Village Name, PCA_ID, Urban/Rural, Ward Population, Subdistrict Population, State Population, Complete ID, Ward Boundary Available with MapSolve, State Shared by MapSolve, State Changed, Ward Boundary Given, TV Boundary Given, SubDistrict Boundary Given, Delivery State, PSU Type, PSU ID, Ward Count, UID, State Code_MapSolve, State Name_MapSolve, District Code_MapSolve, District Name_MapSolve, Subdistrict Code_MapSolve, Subdistrict Name_MapSolve, TV Code_MapSolve, TV Name, Ward Code_MapSolve, Total Population, geometry]
# Index: []
#
# [0 rows x 37 columns]

# %%
combined_gdf = combined_gdf.drop_duplicates(subset=["PSU ID"], keep="first")
len(combined_gdf) == combined_gdf["PSU ID"].nunique()
# Out:
# True

# %%
combined_gdf["UID"] = combined_gdf["UID"].astype(str)

# %%
len(combined_gdf) == combined_gdf["PSU ID"].nunique()
# Out:
# True

# %%
save_shapefiles(
    combined_gdf,
    OUTPUT_DATA_DIR / "Sampled PSUs",
    "all_sampled_PSUs",
    ["csv", "parquet", "kml"],
)
# Out:
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'Greater Mumbai (M Corp.) (Part) WARD NO.-1043' of field all_sampled_PSUs.TV Code parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value '802794-1043' of field all_sampled_PSUs.Ward Code parsed incompletely to real 802794.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Invalid value 'GOOD - Ward boundary given as expected' for boolean field all_sampled_PSUs.TV Boundary Given. Assuming it to be false.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Invalid value 'ward' for boolean field all_sampled_PSUs.SubDistrict Boundary Given. Assuming it to be false.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'Greater Mumbai (M Corp.) (Part) WARD NO.-1144' of field all_sampled_PSUs.TV Code parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value '802794-1144' of field all_sampled_PSUs.Ward Code parsed incompletely to real 802794.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'Greater Mumbai (M Corp.) (Part) WARD NO.-1249' of field all_sampled_PSUs.TV Code parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value '802794-1249' of field all_sampled_PSUs.Ward Code parsed incompletely to real 802794.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'Greater Mumbai (M Corp.) (Part) WARD NO.-1255' of field all_sampled_PSUs.TV Code parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value '802794-1255' of field all_sampled_PSUs.Ward Code parsed incompletely to real 802794.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'Greater Mumbai (M Corp.) (Part) WARD NO.-1256' of field all_sampled_PSUs.TV Code parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value '802794-1256' of field all_sampled_PSUs.Ward Code parsed incompletely to real 802794.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'Greater Mumbai (M Corp.) (Part) WARD NO.-1354' of field all_sampled_PSUs.TV Code parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value '802794-1354' of field all_sampled_PSUs.Ward Code parsed incompletely to real 802794.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'Greater Mumbai (M Corp.) (Part) WARD NO.-1357' of field all_sampled_PSUs.TV Code parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value '802794-1357' of field all_sampled_PSUs.Ward Code parsed incompletely to real 802794.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'Greater Mumbai (M Corp.) (Part) WARD NO.-1458' of field all_sampled_PSUs.TV Code parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value '802794-1458' of field all_sampled_PSUs.Ward Code parsed incompletely to real 802794.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'Greater Mumbai (M Corp.) (Part) WARD NO.-1459' of field all_sampled_PSUs.TV Code parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value '802794-1459' of field all_sampled_PSUs.Ward Code parsed incompletely to real 802794.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'Greater Mumbai (M Corp.) (Part) WARD NO.-1562' of field all_sampled_PSUs.TV Code parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value '802794-1562' of field all_sampled_PSUs.Ward Code parsed incompletely to real 802794.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'Greater Mumbai (M Corp.) (Part) WARD NO.-1978' of field all_sampled_PSUs.TV Code parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value '802794-1978' of field all_sampled_PSUs.Ward Code parsed incompletely to real 802794.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'Greater Mumbai (M Corp.) (Part) WARD NO.-2080' of field all_sampled_PSUs.TV Code parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value '802794-2080' of field all_sampled_PSUs.Ward Code parsed incompletely to real 802794.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'Greater Mumbai (M Corp.) (Part) WARD NO.-2179' of field all_sampled_PSUs.TV Code parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value '802794-2179' of field all_sampled_PSUs.Ward Code parsed incompletely to real 802794.
#   ogr_write(

# %% [markdown]
# ## 5. Download rooftops

# %% [markdown]
# #### Identify S2 cell IDs

# %%
s2_cell_ids = get_s2_cell_ids(combined_gdf)
len(s2_cell_ids)
# Out:
# Shapes with spillover after round 1: 0
# /Users/amiremami/IDinsight Repos/rooftop_sampling/Panel/utils.py:126: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   points = gdf.geometry.centroid.to_frame(name="geometry")
# 1

# %% [markdown]
# #### Check if identified cells cover all areas of interest

# %%
s2_cells_gdf = s2_cell_ids_to_shapes_gdf(s2_cell_ids)

# %%
# Does the S2 cell cover the entire area of the boundaries?
uncovered_area = combined_gdf.unary_union.difference(s2_cells_gdf.unary_union).area
print(f"{uncovered_area} square degrees area not covered by an S2 cell")
# Out:
# 0.0 square degrees area not covered by an S2 cell

# %%
# Plot the S2 cells and the boundary
fig, ax = plt.subplots(1, 1, figsize=(6, 6))
combined_gdf.boundary.plot(ax=ax, color="black", linewidth=1)
s2_cells_gdf.plot(ax=ax, facecolor="none", edgecolor="red", alpha=0.7)
plt.title("S2 Cells Level 6 Coverage")
plt.tight_layout()
plt.show()

# %%
s2_cells_gdf_w_state = (
    s2_cells_gdf.sjoin(
        combined_gdf[["State Name", "geometry"]], how="inner", predicate="intersects"
    )
    .drop(columns="index_right")
    .drop_duplicates()
)

# %%
# note: this will have duplicate s2 cell rows with different state names if the s2 cell overlaps multiple states
# this is expected and is required for the next steps logic to work correctly
s2_cells_gdf_w_state
# Out:
#             s2_cell_id                                           geometry  \
# 0  4316418767857909760  POLYGON ((71.95199 18.67416, 73.46516 18.81752...
#
#     State Name
# 0  Maharashtra

# %% [markdown]
# #### Download the S2 cells

# %%
download_VIDA_rooftops_data_by_s2(s2_cell_ids, "IND", RAW_DATA_DIR / "02. Rooftop Data")
# Out:
# Downloading rooftops by S2 cell:   0%|          | 0/1 [00:00<?, ?it/s]
# File 4316418767857909760 already exists.

# %% [markdown]
# ## 6. Load rooftops and match to areas

# %%
state_names = combined_gdf["State Name"].sort_values().unique()
# state_names = ["Jharkhand", "Odisha", "Chhattisgarh"]

# %%
for state_name in tqdm(state_names):
    print(f"Processing state: {state_name}")

    # Filter the s2 cells and rooftops gdf to the current state
    s2_cell_ids = set(
        s2_cells_gdf_w_state[s2_cells_gdf_w_state["State Name"] == state_name][
            "s2_cell_id"
        ]
    )
    print(
        f"Number of S2 cells that overlap our shapes in {state_name}: {len(s2_cell_ids)}"
    )
    gdf_subset = combined_gdf[combined_gdf["State Name"] == state_name]

    # Get matched rooftops for each S2 cell in the state
    matched_rooftop_centroids_gdf_list = []
    for s2_cell_id in tqdm(s2_cell_ids):
        matched_rooftop_centroids_gdf = get_matched_rooftop_centroids_from_s2_file(
            s2_file_dir=RAW_DATA_DIR / "02. Rooftop Data",
            s2_cell_id=s2_cell_id,
            boundaries_gdf=gdf_subset,
        )
        matched_rooftop_centroids_gdf_list.append(matched_rooftop_centroids_gdf)
    matched_rooftop_centroids_gdf = pd.concat(
        matched_rooftop_centroids_gdf_list, ignore_index=True
    )
    matched_rooftop_centroids_gdf["State Name"] = state_name

    # Save the matched rooftops data
    save_shapefiles(
        matched_rooftop_centroids_gdf,
        CLEANED_DATA_DIR / "01. Matched Rooftop Data" / f"{state_name}",
        "matched_rooftops",
        ["parquet"],
    )
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# Processing state: Maharashtra
# Number of S2 cells that overlap our shapes in Maharashtra: 1
#   0%|          | 0/1 [00:00<?, ?it/s]
# /Users/amiremami/IDinsight Repos/rooftop_sampling/Panel/utils.py:223: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   s2_rooftops_gdf.geometry.centroid

# %%
# ax = matched_rooftop_centroids_gdf.sample(1000).plot(
#     cmap=ListedColormap(generate_colormap(len(matched_rooftop_centroids_gdf))),
# )
# gdf_subset.plot(ax=ax, color="none", edgecolor="black", linewidth=0.5)

# %% [markdown]
# ## 7. Load matched rooftops

# %%
matched_rooftop_dir = CLEANED_DATA_DIR / "01. Matched Rooftop Data"
all_filepaths = list(matched_rooftop_dir.glob("**/*.parquet"))
all_filepaths = [f for f in all_filepaths if f.is_file()]

# filter to those that have selected_states in the name
all_filepaths = [
    f for f in all_filepaths if any(state in f.parent.name for state in state_names)
]

# load all shapes into one gdf
matched_rooftops_gdf_list = []
for filepath in tqdm(all_filepaths):
    matched_rooftops_gdf_list.append(gpd.read_parquet(filepath))
matched_rooftops_gdf = gpd.GeoDataFrame(
    pd.concat(matched_rooftops_gdf_list, ignore_index=True)
).to_crs(4326)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
len(matched_rooftops_gdf)
# Out:
# 128634

# %%
no_rooftop_PSU_IDs = set(combined_gdf[combined_gdf["State Name"].isin(state_names)]["PSU ID"].unique()).difference(
    set(matched_rooftops_gdf["PSU ID"].unique())
)
no_rooftop_PSU_gdf = combined_gdf[combined_gdf["PSU ID"].isin(no_rooftop_PSU_IDs)]
no_rooftop_PSU_gdf
# Out:
# Empty GeoDataFrame
# Columns: [State Code, State Name, District Code, District Name, Subdistrict Code, Subdistrict Name, TV Code, Ward Code, Ward/Village Name, PCA_ID, Urban/Rural, Ward Population, Subdistrict Population, State Population, Complete ID, Ward Boundary Available with MapSolve, State Shared by MapSolve, State Changed, Ward Boundary Given, TV Boundary Given, SubDistrict Boundary Given, Delivery State, PSU Type, PSU ID, Ward Count, UID, State Code_MapSolve, State Name_MapSolve, District Code_MapSolve, District Name_MapSolve, Subdistrict Code_MapSolve, Subdistrict Name_MapSolve, TV Code_MapSolve, TV Name, Ward Code_MapSolve, Total Population, geometry]
# Index: []
#
# [0 rows x 37 columns]

# %%
save_shapefiles(
    no_rooftop_PSU_gdf,
    OUTPUT_DATA_DIR / "Sampled PSUs",
    "PSUs_with_no_rooftops",
    ["csv", "kml"],
)

# %% [markdown]
# ## 8. Sample rooftops

# %%
# Define the base number of rooftops per ward
ROOFTOPS_PER_WARD = 75

# Sample rooftops, multiplying by Ward Count for each PSU.
sampled_rooftops = matched_rooftops_gdf.groupby("PSU ID", group_keys=False).apply(
    lambda x: x.sample(
        n=min(ROOFTOPS_PER_WARD * int(x["Ward Count"].iloc[0]), x.shape[0]),
        random_state=42,
    )
)

# %%
print("Length of matched_rooftops_gdf:", len(matched_rooftops_gdf))
print("Length of sampled rooftops:", len(sampled_rooftops))
# Out:
# Length of matched_rooftops_gdf: 128634
# Length of sampled rooftops: 975

# %%
# Check if Ward Count is correctly influencing sample sizes
TEMP_ward_count_df = matched_rooftops_gdf[["PSU ID", "Ward Count"]].drop_duplicates()
TEMP_ward_count_df["Expected Rooftop Count"] = TEMP_ward_count_df["Ward Count"] * ROOFTOPS_PER_WARD
TEMP_sampled_counts = (
    sampled_rooftops.groupby("PSU ID").size()
).reset_index(name="Sampled Rooftop Count")

# Merge the two dataframes
TEMP_check_df = TEMP_ward_count_df.merge(TEMP_sampled_counts, on="PSU ID")
TEMP_check_df["Rooftop Count Difference"] = (
    TEMP_check_df["Expected Rooftop Count"] - TEMP_check_df["Sampled Rooftop Count"]
)
TEMP_check_df[TEMP_check_df["Rooftop Count Difference"] != 0]
# Out:
# Empty DataFrame
# Columns: [PSU ID, Ward Count, Expected Rooftop Count, Sampled Rooftop Count, Rooftop Count Difference]
# Index: []

# %%
sampled_rooftops.plot(
    figsize=(8, 8),
    column="State Name",
    cmap="tab20",
    edgecolor="black",
    linewidth=0.5,
    legend=True,
)
# Out:
# <Axes: >

# %% [markdown]
# ## Save files

# %% [markdown]
# ### Add sample-level rooftop numbering ID columns

# %%
# Rooftop number within each state
sampled_rooftops["Rooftop State ID"] = (
    sampled_rooftops.groupby("State Name").cumcount() + 1
)

# Rooftop number within each PSU ID
sampled_rooftops["Rooftop PSU ID Numeric"] = sampled_rooftops.groupby("PSU ID").cumcount() + 1
# add prefix of "PIN "  to the Rooftop PSU ID
sampled_rooftops["Rooftop PSU ID"] = "PIN " + sampled_rooftops["Rooftop PSU ID Numeric"].astype(
    str
)

# Rooftop unique ID
sampled_rooftops["Rooftop Unique ID"] = sampled_rooftops.apply(
    lambda row: f"STATE_{row['Rooftop State ID']}_PSU_ID_{row['PSU ID']}_ROOFTOP_{row['Rooftop PSU ID']}",
    axis=1,
)

# %% [markdown]
# ### Add gmap link

# %%
sampled_rooftops["latitude_original"] = sampled_rooftops.geometry.y
sampled_rooftops["longitude_original"] = sampled_rooftops.geometry.x
sampled_rooftops["gmap_link_original"] = create_gmap_links(
    df=sampled_rooftops,
    lat_name="latitude_original",
    lon_name="longitude_original",
)

# %% [markdown]
# ### Select only useful columns

# %% [markdown]
# **Required columns:**
# - PSU info
#     - Unique ID across all rooftops
#     - Rooftop state ID, #
#     - Rooftop PSU ID, #
#
#     - PSU Unit: Ward, TV, Subdistrict
#     - PSU sample size
#
# - geospatial info
#     - google maps link
#     - coordinates
#     - geometry
#
# - Admin location info
#     - State code and name
#     - District code and Name
#     - Subdistrict code and name
#     - TV code and name
#     - Ward code and name

# %%
chosen_cols = [
    ## IDs
    "Rooftop State ID",
    "Rooftop PSU ID",
    "Rooftop PSU ID Numeric",
    "Rooftop Unique ID",
    ## Geospatial data
    "geometry",
    "latitude_original",
    "longitude_original",
    "gmap_link_original",
    ## PSU info
    "PSU ID",
    "PSU Type",
    "Ward Count",
    ## Location info
    "State Code",
    "State Name",
    "State Changed",
    "District Code",
    "District Name",
    "Subdistrict Code",
    "Subdistrict Name",
    "TV Code",
    "TV Name",  # (from MapSolve)
    "Ward Code",
    "Ward/Village Name",
    "Urban/Rural",
    "PCA_ID",  # combined TVCode-WardCode
    "Ward Population",
    "Subdistrict Population",
    "State Population",
    # "Complete ID",
    ## Admin information
    # "Included in Panel",
    "Ward Boundary Available with MapSolve",
    # "State Shared by MapSolve",
    "Ward Boundary Given",
    "TV Boundary Given",
    "SubDistrict Boundary Given",
    "Delivery State",
    # "UID",
    # "s2_rooftop_id",
    ## MapSolve location info
    "State Code_MapSolve",
    "State Name_MapSolve",
    "District Code_MapSolve",
    "District Name_MapSolve",
    "Subdistrict Code_MapSolve",
    "Subdistrict Name_MapSolve",
    "TV Code_MapSolve",
    # "TV Name",
    "Ward Code_MapSolve",
    # "PCA_ID_MapSolve",
    "Total Population",
    # ## rooftop info
    # "boundary_id",
    # "bf_source",
    # "confidence",
    # "area_in_meters",
    # "s2_id",
    # "country_iso",
    # "geohash",
    # "bbox",
]

# %%
sampled_rooftops_organised_gdf = sampled_rooftops[chosen_cols]

# %%
sampled_rooftops_organised_gdf.rename(
    columns={
        "TV Name": "TV Name_MapSolve",
        "PSU ID": "PSU ID",
        "Total Population": "PSU Total Population_MapSolve",
    },
    inplace=True,
)
# Out:
# /var/folders/99/cwxq7sdx5d94rqxj57_crqbc0000gn/T/ipykernel_4977/357453037.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sampled_rooftops_organised_gdf.rename(

# %%
# set Ward Codes of 0.0 to NaN
sampled_rooftops_organised_gdf.loc[
    sampled_rooftops_organised_gdf["Ward Code"] == 0.0, "Ward Code"
] = np.nan

# %%
sampled_rooftops_organised_gdf
# Out:
#        Rooftop State ID Rooftop PSU ID  Rooftop PSU ID Numeric  \
# 2959                  1          PIN 1                       1
# 3381                  2          PIN 2                       2
# 2628                  3          PIN 3                       3
# 4261                  4          PIN 4                       4
# 4828                  5          PIN 5                       5
# ...                 ...            ...                     ...
# 16161               971         PIN 71                      71
# 16256               972         PIN 72                      72
# 16436               973         PIN 73                      73
# 15304               974         PIN 74                      74
# 15214               975         PIN 75                      75
#
#                                       Rooftop Unique ID  \
# 2959      STATE_1_PSU_ID_WARD_802794-1043_ROOFTOP_PIN 1
# 3381      STATE_2_PSU_ID_WARD_802794-1043_ROOFTOP_PIN 2
# 2628      STATE_3_PSU_ID_WARD_802794-1043_ROOFTOP_PIN 3
# 4261      STATE_4_PSU_ID_WARD_802794-1043_ROOFTOP_PIN 4
# 4828      STATE_5_PSU_ID_WARD_802794-1043_ROOFTOP_PIN 5
# ...                                                 ...
# 16161  STATE_971_PSU_ID_WARD_802794-2179_ROOFTOP_PIN 71
# 16256  STATE_972_PSU_ID_WARD_802794-2179_ROOFTOP_PIN 72
# 16436  STATE_973_PSU_ID_WARD_802794-2179_ROOFTOP_PIN 73
# 15304  STATE_974_PSU_ID_WARD_802794-2179_ROOFTOP_PIN 74
# 15214  STATE_975_PSU_ID_WARD_802794-2179_ROOFTOP_PIN 75
#
#                         geometry  latitude_original  longitude_original  \
# 2959   POINT (72.84348 19.06830)          19.068298           72.843478
# 3381   POINT (72.84264 19.06986)          19.069862           72.842642
# 2628   POINT (72.84380 19.06776)          19.067759           72.843801
# 4261   POINT (72.84611 19.06712)          19.067115           72.846115
# 4828   POINT (72.84815 19.06945)          19.069452           72.848147
# ...                          ...                ...                 ...
# 16161  POINT (72.91288 19.05905)          19.059047           72.912875
# 16256  POINT (72.91119 19.06121)          19.061213           72.911192
# 16436  POINT (72.91080 19.06351)          19.063509           72.910800
# 15304  POINT (72.90873 19.05987)          19.059868           72.908730
# 15214  POINT (72.90864 19.05941)          19.059413           72.908638
#
#                                       gmap_link_original            PSU ID  \
# 2959   https://www.google.com/maps/search/?api=1&quer...  WARD_802794-1043
# 3381   https://www.google.com/maps/search/?api=1&quer...  WARD_802794-1043
# 2628   https://www.google.com/maps/search/?api=1&quer...  WARD_802794-1043
# 4261   https://www.google.com/maps/search/?api=1&quer...  WARD_802794-1043
# 4828   https://www.google.com/maps/search/?api=1&quer...  WARD_802794-1043
# ...                                                  ...               ...
# 16161  https://www.google.com/maps/search/?api=1&quer...  WARD_802794-2179
# 16256  https://www.google.com/maps/search/?api=1&quer...  WARD_802794-2179
# 16436  https://www.google.com/maps/search/?api=1&quer...  WARD_802794-2179
# 15304  https://www.google.com/maps/search/?api=1&quer...  WARD_802794-2179
# 15214  https://www.google.com/maps/search/?api=1&quer...  WARD_802794-2179
#
#       PSU Type  ...                          Delivery State  \
# 2959      ward  ...  GOOD - Ward boundary given as expected
# 3381      ward  ...  GOOD - Ward boundary given as expected
# 2628      ward  ...  GOOD - Ward boundary given as expected
# 4261      ward  ...  GOOD - Ward boundary given as expected
# 4828      ward  ...  GOOD - Ward boundary given as expected
# ...        ...  ...                                     ...
# 16161     ward  ...  GOOD - Ward boundary given as expected
# 16256     ward  ...  GOOD - Ward boundary given as expected
# 16436     ward  ...  GOOD - Ward boundary given as expected
# 15304     ward  ...  GOOD - Ward boundary given as expected
# 15214     ward  ...  GOOD - Ward boundary given as expected
#
#        State Code_MapSolve State Name_MapSolve District Code_MapSolve  \
# 2959                  27.0         Maharashtra                    NaN
# 3381                  27.0         Maharashtra                    NaN
# 2628                  27.0         Maharashtra                    NaN
# 4261                  27.0         Maharashtra                    NaN
# 4828                  27.0         Maharashtra                    NaN
# ...                    ...                 ...                    ...
# 16161                 27.0         Maharashtra                    NaN
# 16256                 27.0         Maharashtra                    NaN
# 16436                 27.0         Maharashtra                    NaN
# 15304                 27.0         Maharashtra                    NaN
# 15214                 27.0         Maharashtra                    NaN
#
#        District Name_MapSolve Subdistrict Code_MapSolve  \
# 2959                     None                   99999.0
# 3381                     None                   99999.0
# 2628                     None                   99999.0
# 4261                     None                   99999.0
# 4828                     None                   99999.0
# ...                       ...                       ...
# 16161                    None                   99999.0
# 16256                    None                   99999.0
# 16436                    None                   99999.0
# 15304                    None                   99999.0
# 15214                    None                   99999.0
#
#        Subdistrict Name_MapSolve TV Code_MapSolve  Ward Code_MapSolve  \
# 2959                        None         802794.0              1043.0
# 3381                        None         802794.0              1043.0
# 2628                        None         802794.0              1043.0
# 4261                        None         802794.0              1043.0
# 4828                        None         802794.0              1043.0
# ...                          ...              ...                 ...
# 16161                       None         802794.0              2179.0
# 16256                       None         802794.0              2179.0
# 16436                       None         802794.0              2179.0
# 15304                       None         802794.0              2179.0
# 15214                       None         802794.0              2179.0
#
#       PSU Total Population_MapSolve
# 2959                        99427.0
# 3381                        99427.0
# 2628                        99427.0
# 4261                        99427.0
# 4828                        99427.0
# ...                             ...
# 16161                      357518.0
# 16256                      357518.0
# 16436                      357518.0
# 15304                      357518.0
# 15214                      357518.0
#
# [975 rows x 41 columns]

# %% [markdown]
# ### Save sampled data (original rooftop pins)

# %%
sampled_rooftops_organised_gdf["Subdistrict Population"] = sampled_rooftops_organised_gdf["Subdistrict Population"].astype(str)
sampled_rooftops_organised_gdf["State Population"] = sampled_rooftops_organised_gdf["State Population"].astype(str)
# Out:
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/geopandas/geodataframe.py:1543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/geopandas/geodataframe.py:1543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
save_shapefiles(
    sampled_rooftops_organised_gdf,
    OUTPUT_DATA_DIR / "01. Sampled Rooftop Data",
    "sampled_rooftops_centroids_original",
    ["csv", "parquet"],
)

save_shapefiles(
    sampled_rooftops_organised_gdf.drop(columns=["gmap_link_original"]),
    OUTPUT_DATA_DIR / "01. Sampled Rooftop Data",
    "sampled_rooftops_centroids_original",
    ["kml"],
)
# Out:
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.068298014750795.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1043' of field sampled_rooftops_centroids_original.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'ward' of field sampled_rooftops_centroids_original.longitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'No' of field sampled_rooftops_centroids_original.State Code parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'Urban' of field sampled_rooftops_centroids_original.Ward Code parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Invalid value 'GOOD - Ward boundary given as expected' for boolean field sampled_rooftops_centroids_original.TV Boundary Given. Assuming it to be false.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.SubDistrict Boundary Given: Only 0 or 1 should be passed for a OFSTBoolean subtype. Considering non-zero value 27 as 1.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.069862206598341.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.06775859848705.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.067115296547676.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.069452239588294.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.069137202249486.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.068123704741144.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.071851710322623.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.066961765272783.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.066034391706861.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.074088426044579.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.068240627353649.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.068171905654211.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.06973363320974.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.072862001796032.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.074117717408459.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.074442110065387.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.06918680503064.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.072614538668152.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.069250810159133.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.071053660833389.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.066352341866221.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.071651658274.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.074018093231587.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.068532257520395.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.068106174384649.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.069333150231646.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.068980462126383.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.066553058513925.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.068894454131854.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.072044058473868.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.071420626064469.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.069914607169196.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.067724731670594.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.071592640251922.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.073585795333198.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.073993944301467.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.065637822023294.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.068551628781293.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.074613046604334.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.068174053097859.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.068761060271548.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.070393864114102.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.072272451830695.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.068757116224866.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.067846895754275.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.074542521224583.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.072742061905288.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.07313632741484.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.070359975875963.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.067725960359098.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.072278438342693.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.074118728654657.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.064473578470711.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.069613796939336.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.067054156713365.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.067551200981118.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.065874354567562.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.071677683752853.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.069394741429601.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.06479031143639.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.074370581234014.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.068000219492642.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.073582798009777.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.074378393798426.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.068305869128753.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.070995206748051.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.073439078733308.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.074268084956891.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.0740416554546.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.073480744825019.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.070395597955184.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.069565509244388.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.07031943259252.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.072893737850116.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.063135322874135.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1144' of field sampled_rooftops_centroids_original.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.066353756120382.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.065254519433584.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.064162236637664.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.064613748496676.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.064649651017682.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.067360432639422.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.06192495768709.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.061791525781612.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.05990594133679.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.063652868501727.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.061336726319485.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.062903564078621.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.06076682340063.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.060470075933658.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.066154288757019.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.06517792038191.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.067562607476564.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.0625379386397.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.067641001301247.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.064133909732007.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.0660110462102.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.065083923367506.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.063958048622894.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.061547113085361.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.063884723188458.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.061337972889859.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.067405122298982.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.061958429032014.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.067077973306599.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.064400029992584.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.059919438670089.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.066477522577916.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.061707509216621.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.066178897325372.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.059771353778835.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.061930399068249.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.06486451280151.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.065773716842532.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.06645894101883.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.064207519111942.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.060835730858916.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.065355496358382.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.064658369119552.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.064317470960617.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.063549437117697.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.061724550424223.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.060321760137008.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.065277168607949.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.061232603737533.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.066878411704472.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.060454552762668.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.062413832468835.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.060038425074303.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.062222329398441.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.066484488869282.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.066695330823784.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.060236337594358.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.064639060440502.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.061487120107802.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.063716359926914.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.066438625478241.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.065782480982051.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.060634524195663.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.065959142662784.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.059638992050775.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.065917667688336.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.066373160333825.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.061997213072612.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.061368987294639.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.063062297377495.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.064340670555122.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.066167126194696.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.065445672722539.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.060380911037484.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.099958206629111.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1249' of field sampled_rooftops_centroids_original.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.094261383121854.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.100985291701651.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.100987320266348.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.097587835507785.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.105420564107462.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.097674474968944.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.109140461450544.
#   ogr_write(
# ...
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.058844501282799.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.05924345999431.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.060493456433527.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.06024851226276.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.058959148015646.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.066719453884776.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.065767424433567.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.059476803319768.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.060248212207249.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.059492742657973.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.059252833324052.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.058034117220512.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.060329412024167.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.0620166128497.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.058384523281667.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.059228634159009.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.06138824995973.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.059779765688535.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.061516424807422.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.059366328483787.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.059305547971515.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.058564682470493.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.05956216924233.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.058685753422012.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.064603695583692.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.060007178312109.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.059171400285067.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.059686610979711.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.06000834249966.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.059598076992142.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.061025407435377.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.059192383067334.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.058663649648967.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.061738811188459.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.063440706490084.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.058512170205045.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.064511946800916.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.064281577510254.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.060039403535388.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.057838655473013.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.059878351051601.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.060233973777827.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.058789224789958.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.06347010955032.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.063028208346196.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.05954951103617.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.059158257464645.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.058747888497042.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.059716581348887.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.060554987433402.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.05904667498783.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.061212716881951.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.063508862153757.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.059868254926876.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.059413264631761.
#   ogr_write(

# %% [markdown]
# ## 9. Snap points to road

# %%
import yaml
from shapely import Point

from utils import get_nearest_points_on_road_batch, get_nearest_points_on_road_batch_parallel

# %%
# load API key
with open("../secrets/api_keys.yaml", "r") as f:
    config = yaml.safe_load(f)
    api_key = config["GOOGLE_ROADS_API_KEY"]

# %%
get_nearest_points_on_road_batch([Point(77.11432151622034, 28.677391409999522)], api_key)
# Out:
# [<POINT (77.114 28.677)>]

# %%
# test
get_nearest_points_on_road_batch(sampled_rooftops_organised_gdf.geometry.iloc[:5], api_key)
# Out:
# [<POINT (72.843 19.069)>,
#  <POINT (72.843 19.07)>,
#  <POINT (72.844 19.067)>,
#  <POINT (72.846 19.067)>,
#  <POINT (72.849 19.069)>]

# %%
get_nearest_points_on_road_batch_parallel(sampled_rooftops_organised_gdf.iloc[:150], api_key)
# Out:
# Snapping points to roads (batched):   0%|          | 0/2 [00:00<?, ?it/s]
# 2959    POINT (72.84316 19.06878)
# 3381    POINT (72.84310 19.06986)
# 2628    POINT (72.84433 19.06747)
# 4261    POINT (72.84634 19.06711)
# 4828    POINT (72.84858 19.06938)
#                   ...
# 930     POINT (72.83645 19.06307)
# 622     POINT (72.83117 19.06427)
# 1125    POINT (72.83649 19.06630)
# 1022    POINT (72.83489 19.06569)
# 115     POINT (72.83369 19.06032)
# Length: 150, dtype: geometry

# %% [markdown]
# #### Snap points to road

# %%
snapped_points_series = get_nearest_points_on_road_batch_parallel(
    sampled_rooftops_organised_gdf, api_key, max_workers=12
)
# took 1 second for 1,600 points (Panel)
# 30s for all 53,000 points
# Out:
# Snapping points to roads (batched):   0%|          | 0/10 [00:00<?, ?it/s]

# %%
sampled_rooftops_snapped_gdf = sampled_rooftops_organised_gdf.copy()
sampled_rooftops_snapped_gdf["geometry_snapped"] = sampled_rooftops_snapped_gdf.index.map(snapped_points_series)

# %%
# Make new Geometry Type column which has values "Original" or "Snapped to Road"
sampled_rooftops_snapped_gdf["Geometry Type"] = (
    sampled_rooftops_snapped_gdf["geometry_snapped"]
    .notna()
    .replace({True: "Snapped to Road", False: "Original"})
)
sampled_rooftops_snapped_gdf["Geometry Type"].value_counts()
# Out:
# Geometry Type
# Snapped to Road    933
# Original            42
# Name: count, dtype: int64

# %% [markdown]
# #### Replace geometry to snapped one (missing filled in with original)

# %%
# backup the original geometry
sampled_rooftops_snapped_gdf["geometry_original"] = sampled_rooftops_snapped_gdf[
    "geometry"
]
# replace the original geometry with the snapped geometry
sampled_rooftops_snapped_gdf["geometry"] = sampled_rooftops_snapped_gdf[
    "geometry_snapped"
]
# drop the snapped geometry column
sampled_rooftops_snapped_gdf = sampled_rooftops_snapped_gdf.drop(
    columns=["geometry_snapped"]
)
# fill in NaN values in the snapped geometry with the original geometry
sampled_rooftops_snapped_gdf["geometry"] = sampled_rooftops_snapped_gdf[
    "geometry"
].fillna(sampled_rooftops_snapped_gdf["geometry_original"])

# %%
sampled_rooftops_snapped_gdf["geometry"].isna().sum()
# Out:
# 0

# %% [markdown]
# #### Update lat, lon, gmap_link

# %%
sampled_rooftops_snapped_gdf["latitude"] = list(sampled_rooftops_snapped_gdf.geometry.y)
sampled_rooftops_snapped_gdf["longitude"] = list(
    sampled_rooftops_snapped_gdf.geometry.x
)
sampled_rooftops_snapped_gdf["gmap_link"] = create_gmap_links(
    df=sampled_rooftops_snapped_gdf,
    lat_name="latitude",
    lon_name="longitude",
)

# %% [markdown]
# #### Reorganise

# %%
sampled_rooftops_snapped_gdf = sampled_rooftops_snapped_gdf[
    [
        "Rooftop State ID",
        "Rooftop PSU ID",
        "Rooftop PSU ID Numeric",
        "Rooftop Unique ID",
        # new columns start
        "Geometry Type",
        "geometry",
        "latitude",
        "longitude",
        "gmap_link",
        # new columns end
        "geometry_original",
        "latitude_original",
        "longitude_original",
        "gmap_link_original",
        "PSU ID",
        "PSU Type",
        "Ward Count",
        "State Code",
        "State Name",
        "State Changed",
        "District Code",
        "District Name",
        "Subdistrict Code",
        "Subdistrict Name",
        "TV Code",
        "TV Name_MapSolve",
        "Ward Code",
        "Ward/Village Name",
        "Urban/Rural",
        "PCA_ID",
        "Ward Population",
        "Subdistrict Population",
        "State Population",
        # "Included in Panel",
        "Ward Boundary Available with MapSolve",
        "Ward Boundary Given",
        "TV Boundary Given",
        "SubDistrict Boundary Given",
        "Delivery State",
        "State Code_MapSolve",
        "State Name_MapSolve",
        "District Code_MapSolve",
        "District Name_MapSolve",
        "Subdistrict Code_MapSolve",
        "Subdistrict Name_MapSolve",
        "TV Code_MapSolve",
        "Ward Code_MapSolve",
        # "PCA_ID_MapSolve",
        "PSU Total Population_MapSolve",
    ]
]

# %% [markdown]
# #### Make lines between original and snapped points

# %%
from shapely.geometry import LineString

# %%
sampled_rooftops_snapped_gdf["geometry_line"] = sampled_rooftops_snapped_gdf.apply(
    lambda row: LineString([row["geometry_original"], row["geometry"]]), axis=1
)

# %%
sampled_rooftops_snapped_gdf["geometry_line"].isna().sum()
# Out:
# 0

# %% [markdown]
# #### Save new files: snapped points, snapped lines

# %%
# Save CSV and parquet
save_shapefiles(
    sampled_rooftops_snapped_gdf.drop(
        columns=[
            "geometry_original",
            "geometry_line",
        ]
    ),
    OUTPUT_DATA_DIR / "01. Sampled Rooftop Data",
    "sampled_rooftops_snapped_points",
    ["csv", "parquet"],
)

# %%
# Save KML
save_shapefiles(
    sampled_rooftops_snapped_gdf.drop(
        columns=[
            "geometry_original",
            "geometry_line",
            # bad cols for KML
            "gmap_link_original",
            "gmap_link"
        ]
    ),
    OUTPUT_DATA_DIR / "01. Sampled Rooftop Data",
    "sampled_rooftops_snapped_points",
    ["kml"],
)
# Out:
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1043' of field sampled_rooftops_snapped_points.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'ward' of field sampled_rooftops_snapped_points.longitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'No' of field sampled_rooftops_snapped_points.State Code parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'Urban' of field sampled_rooftops_snapped_points.Ward Code parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Invalid value 'GOOD - Ward boundary given as expected' for boolean field sampled_rooftops_snapped_points.TV Boundary Given. Assuming it to be false.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_snapped_points.SubDistrict Boundary Given: Only 0 or 1 should be passed for a OFSTBoolean subtype. Considering non-zero value 27 as 1.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1144' of field sampled_rooftops_snapped_points.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1249' of field sampled_rooftops_snapped_points.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1255' of field sampled_rooftops_snapped_points.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1256' of field sampled_rooftops_snapped_points.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1354' of field sampled_rooftops_snapped_points.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1357' of field sampled_rooftops_snapped_points.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1458' of field sampled_rooftops_snapped_points.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1459' of field sampled_rooftops_snapped_points.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1562' of field sampled_rooftops_snapped_points.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1978' of field sampled_rooftops_snapped_points.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-2080' of field sampled_rooftops_snapped_points.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-2179' of field sampled_rooftops_snapped_points.latitude_original parsed incompletely to real 0.
#   ogr_write(

# %%
# Save lines
sampled_rooftops_line_gdf = sampled_rooftops_snapped_gdf.copy()
sampled_rooftops_line_gdf["geometry"] = sampled_rooftops_line_gdf["geometry_line"]
sampled_rooftops_line_gdf = sampled_rooftops_line_gdf.drop(
    columns=["geometry_original", "geometry_line"]
)

# %%
save_shapefiles(
    sampled_rooftops_line_gdf.drop(
        # drop kml unfriendly columns
        columns=["gmap_link_original", "gmap_link"]
    ),
    OUTPUT_DATA_DIR / "01. Sampled Rooftop Data",
    "sampled_rooftops_snapped_lines",
    ["parquet", "kml"],
)
# Out:
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1043' of field sampled_rooftops_snapped_lines.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'ward' of field sampled_rooftops_snapped_lines.longitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'No' of field sampled_rooftops_snapped_lines.State Code parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'Urban' of field sampled_rooftops_snapped_lines.Ward Code parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Invalid value 'GOOD - Ward boundary given as expected' for boolean field sampled_rooftops_snapped_lines.TV Boundary Given. Assuming it to be false.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field sampled_rooftops_snapped_lines.SubDistrict Boundary Given: Only 0 or 1 should be passed for a OFSTBoolean subtype. Considering non-zero value 27 as 1.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1144' of field sampled_rooftops_snapped_lines.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1249' of field sampled_rooftops_snapped_lines.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1255' of field sampled_rooftops_snapped_lines.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1256' of field sampled_rooftops_snapped_lines.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1354' of field sampled_rooftops_snapped_lines.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1357' of field sampled_rooftops_snapped_lines.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1458' of field sampled_rooftops_snapped_lines.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1459' of field sampled_rooftops_snapped_lines.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1562' of field sampled_rooftops_snapped_lines.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1978' of field sampled_rooftops_snapped_lines.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-2080' of field sampled_rooftops_snapped_lines.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-2179' of field sampled_rooftops_snapped_lines.latitude_original parsed incompletely to real 0.
#   ogr_write(

# %% [markdown]
# ## Save per state

# %%
for state in tqdm(sampled_rooftops_organised_gdf["State Name"].unique()):
    state_output_folder = OUTPUT_DATA_DIR / "01. Sampled Rooftop Data" / "State-Level" / state

    # save original points
    selected_state_original_gdf = sampled_rooftops_organised_gdf[
        sampled_rooftops_organised_gdf["State Name"] == state
    ]

    save_shapefiles(
        selected_state_original_gdf,
        state_output_folder,
        f"{state}_sampled_rooftops_centroids_original",
        ["csv", "parquet"],
    )
    save_shapefiles(
        selected_state_original_gdf.drop(
            # drop kml unfriendly columns
            columns=["gmap_link_original"]
        ),
        state_output_folder,
        f"{state}_sampled_rooftops_centroids_original",
        ["kml"],
    )

    # Save snapped points
    selected_state_snapped_gdf = sampled_rooftops_snapped_gdf[
        sampled_rooftops_snapped_gdf["State Name"] == state
    ].drop(
        columns=[
            "geometry_original",
            "geometry_line",
        ]
    )
    save_shapefiles(
        selected_state_snapped_gdf,
        state_output_folder,
        f"{state}_sampled_rooftops_snapped_points",
        ["csv", "parquet"],
    )
    save_shapefiles(
        selected_state_snapped_gdf.drop(
            # drop kml unfriendly columns
            columns=["gmap_link_original", "gmap_link"]
        ),
        state_output_folder,
        f"{state}_sampled_rooftops_snapped_points",
        ["kml"],
    )

    # Save lines
    selected_state_sampled_rooftops_line_gdf = sampled_rooftops_line_gdf[
        sampled_rooftops_line_gdf["State Name"] == state
    ]
    save_shapefiles(
        selected_state_sampled_rooftops_line_gdf.drop(
            # drop kml unfriendly columns
            columns=["gmap_link_original", "gmap_link"]
        ),
        state_output_folder,
        f"{state}_sampled_rooftops_snapped_lines",
        ["parquet", "kml"],
    )
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.068298014750795.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1043' of field Maharashtra_sampled_rooftops_centroids_original.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'ward' of field Maharashtra_sampled_rooftops_centroids_original.longitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'No' of field Maharashtra_sampled_rooftops_centroids_original.State Code parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'Urban' of field Maharashtra_sampled_rooftops_centroids_original.Ward Code parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Invalid value 'GOOD - Ward boundary given as expected' for boolean field Maharashtra_sampled_rooftops_centroids_original.TV Boundary Given. Assuming it to be false.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.SubDistrict Boundary Given: Only 0 or 1 should be passed for a OFSTBoolean subtype. Considering non-zero value 27 as 1.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.069862206598341.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.06775859848705.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.067115296547676.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.069452239588294.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.069137202249486.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.068123704741144.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.071851710322623.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.066961765272783.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.066034391706861.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.074088426044579.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.068240627353649.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.068171905654211.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.06973363320974.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.072862001796032.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.074117717408459.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.074442110065387.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.06918680503064.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.072614538668152.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.069250810159133.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.071053660833389.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.066352341866221.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.071651658274.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.074018093231587.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.068532257520395.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.068106174384649.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.069333150231646.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.068980462126383.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.066553058513925.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.068894454131854.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.072044058473868.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.071420626064469.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.069914607169196.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.067724731670594.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.071592640251922.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.073585795333198.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.073993944301467.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.065637822023294.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.068551628781293.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.074613046604334.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.068174053097859.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.068761060271548.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.070393864114102.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.072272451830695.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.068757116224866.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.067846895754275.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.074542521224583.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.072742061905288.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.07313632741484.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.070359975875963.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.067725960359098.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.072278438342693.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.074118728654657.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.064473578470711.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.069613796939336.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.067054156713365.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.067551200981118.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.065874354567562.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.071677683752853.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.069394741429601.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.06479031143639.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.074370581234014.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.068000219492642.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.073582798009777.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.074378393798426.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.068305869128753.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.070995206748051.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.073439078733308.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.074268084956891.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.0740416554546.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.073480744825019.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.070395597955184.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.069565509244388.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.07031943259252.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.072893737850116.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.063135322874135.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1144' of field Maharashtra_sampled_rooftops_centroids_original.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.066353756120382.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.065254519433584.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.064162236637664.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.064613748496676.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.064649651017682.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.067360432639422.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.06192495768709.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.061791525781612.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.05990594133679.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.063652868501727.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.061336726319485.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.062903564078621.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.06076682340063.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.060470075933658.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.066154288757019.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.06517792038191.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.067562607476564.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.0625379386397.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.067641001301247.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.064133909732007.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.0660110462102.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.065083923367506.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.063958048622894.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.061547113085361.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.063884723188458.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.061337972889859.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.067405122298982.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.061958429032014.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.067077973306599.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.064400029992584.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.059919438670089.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.066477522577916.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.061707509216621.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.066178897325372.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.059771353778835.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.061930399068249.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.06486451280151.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.065773716842532.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.06645894101883.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.064207519111942.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.060835730858916.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.065355496358382.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.064658369119552.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.064317470960617.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.063549437117697.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.061724550424223.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.060321760137008.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.065277168607949.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.061232603737533.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.066878411704472.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.060454552762668.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.062413832468835.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.060038425074303.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.062222329398441.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.066484488869282.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.066695330823784.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.060236337594358.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.064639060440502.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.061487120107802.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.063716359926914.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.066438625478241.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.065782480982051.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.060634524195663.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.065959142662784.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.059638992050775.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.065917667688336.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.066373160333825.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.061997213072612.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.061368987294639.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.063062297377495.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.064340670555122.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.066167126194696.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.065445672722539.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.060380911037484.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.099958206629111.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1249' of field Maharashtra_sampled_rooftops_centroids_original.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.094261383121854.
#   ogr_write(
# ...
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.058663649648967.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.061738811188459.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.063440706490084.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.058512170205045.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.064511946800916.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.064281577510254.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.060039403535388.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.057838655473013.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.059878351051601.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.060233973777827.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.058789224789958.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.06347010955032.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.063028208346196.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.05954951103617.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.059158257464645.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.058747888497042.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.059716581348887.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.060554987433402.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.05904667498783.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.061212716881951.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.063508862153757.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.059868254926876.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.059413264631761.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1043' of field Maharashtra_sampled_rooftops_snapped_points.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'ward' of field Maharashtra_sampled_rooftops_snapped_points.longitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'No' of field Maharashtra_sampled_rooftops_snapped_points.State Code parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'Urban' of field Maharashtra_sampled_rooftops_snapped_points.Ward Code parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Invalid value 'GOOD - Ward boundary given as expected' for boolean field Maharashtra_sampled_rooftops_snapped_points.TV Boundary Given. Assuming it to be false.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_snapped_points.SubDistrict Boundary Given: Only 0 or 1 should be passed for a OFSTBoolean subtype. Considering non-zero value 27 as 1.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1144' of field Maharashtra_sampled_rooftops_snapped_points.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1249' of field Maharashtra_sampled_rooftops_snapped_points.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1255' of field Maharashtra_sampled_rooftops_snapped_points.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1256' of field Maharashtra_sampled_rooftops_snapped_points.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1354' of field Maharashtra_sampled_rooftops_snapped_points.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1357' of field Maharashtra_sampled_rooftops_snapped_points.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1458' of field Maharashtra_sampled_rooftops_snapped_points.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1459' of field Maharashtra_sampled_rooftops_snapped_points.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1562' of field Maharashtra_sampled_rooftops_snapped_points.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1978' of field Maharashtra_sampled_rooftops_snapped_points.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-2080' of field Maharashtra_sampled_rooftops_snapped_points.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-2179' of field Maharashtra_sampled_rooftops_snapped_points.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1043' of field Maharashtra_sampled_rooftops_snapped_lines.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'ward' of field Maharashtra_sampled_rooftops_snapped_lines.longitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'No' of field Maharashtra_sampled_rooftops_snapped_lines.State Code parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'Urban' of field Maharashtra_sampled_rooftops_snapped_lines.Ward Code parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Invalid value 'GOOD - Ward boundary given as expected' for boolean field Maharashtra_sampled_rooftops_snapped_lines.TV Boundary Given. Assuming it to be false.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_snapped_lines.SubDistrict Boundary Given: Only 0 or 1 should be passed for a OFSTBoolean subtype. Considering non-zero value 27 as 1.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1144' of field Maharashtra_sampled_rooftops_snapped_lines.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1249' of field Maharashtra_sampled_rooftops_snapped_lines.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1255' of field Maharashtra_sampled_rooftops_snapped_lines.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1256' of field Maharashtra_sampled_rooftops_snapped_lines.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1354' of field Maharashtra_sampled_rooftops_snapped_lines.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1357' of field Maharashtra_sampled_rooftops_snapped_lines.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1458' of field Maharashtra_sampled_rooftops_snapped_lines.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1459' of field Maharashtra_sampled_rooftops_snapped_lines.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1562' of field Maharashtra_sampled_rooftops_snapped_lines.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1978' of field Maharashtra_sampled_rooftops_snapped_lines.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-2080' of field Maharashtra_sampled_rooftops_snapped_lines.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-2179' of field Maharashtra_sampled_rooftops_snapped_lines.latitude_original parsed incompletely to real 0.
#   ogr_write(

# %% [markdown]
# ### Save slices per state

# %%
from math import ceil
SLICE_SIZE = 25
N_SLICES = ceil(ROOFTOPS_PER_WARD / SLICE_SIZE)

print(f"ROOFTOPS_PER_WARD: {ROOFTOPS_PER_WARD}")
print(f"SLICE_SIZE: {SLICE_SIZE}")
print(f"N_SLICES: {N_SLICES}")
print(f"N_SLICES * SLICE_SIZE: {N_SLICES * SLICE_SIZE}")
# Out:
# ROOFTOPS_PER_WARD: 75
# SLICE_SIZE: 25
# N_SLICES: 3
# N_SLICES * SLICE_SIZE: 75

# %%
sampled_rooftops_organised_gdf["State Name"].unique()
# Out:
# array(['Maharashtra'], dtype=object)

# %%
for state in tqdm(sampled_rooftops_organised_gdf["State Name"].unique()):
    state_gdf = sampled_rooftops_organised_gdf[
        sampled_rooftops_organised_gdf["State Name"] == state
    ]
    for slice_idx in range(N_SLICES):

        original_points_slice_rows = []
        snapped_points_slice_rows = []
        line_slice_rows = []

        for psu_id, psu_df in state_gdf.groupby("PSU ID"):
            # get counts and indices from the original dataframe (also applies to the other two)
            ward_count = int(psu_df["Ward Count"].iloc[0])
            start_idx = slice_idx * SLICE_SIZE * ward_count
            end_idx = start_idx + (SLICE_SIZE * ward_count)

            # original points
            psu_original_slice = sampled_rooftops_organised_gdf[
                (sampled_rooftops_organised_gdf["State Name"] == state)
                & (sampled_rooftops_organised_gdf["PSU ID"] == psu_id)
            ].iloc[start_idx:end_idx]
            original_points_slice_rows.append(psu_original_slice)

            # snapped points
            psu_snapped_slice = sampled_rooftops_snapped_gdf[
                (sampled_rooftops_snapped_gdf["State Name"] == state)
                & (sampled_rooftops_snapped_gdf["PSU ID"] == psu_id)
            ].iloc[start_idx:end_idx]
            snapped_points_slice_rows.append(psu_snapped_slice)

            # lines
            psu_line_slice = sampled_rooftops_line_gdf[
                (sampled_rooftops_line_gdf["State Name"] == state)
                & (sampled_rooftops_line_gdf["PSU ID"] == psu_id)
            ].iloc[start_idx:end_idx]
            line_slice_rows.append(psu_line_slice)


        # Concatenate all PSU slices for this state and slice
        state_slice_original_gdf = pd.concat(original_points_slice_rows, ignore_index=True)
        state_slice_snapped_gdf = pd.concat(snapped_points_slice_rows, ignore_index=True)
        state_slice_line_gdf = pd.concat(line_slice_rows, ignore_index=True)

        # set folder
        state_slice_output_folder = (
            OUTPUT_DATA_DIR
            / "01. Sampled Rooftop Data"
            / "State-Level"
            / state
            / f"slice_{slice_idx}"
        )

        # Save original points
        save_shapefiles(
            state_slice_original_gdf,
            state_slice_output_folder,
            f"{state}_sampled_rooftops_centroids_original_{slice_idx}",
            ["csv", "parquet"],
        )
        save_shapefiles(
            state_slice_original_gdf.drop(columns=["gmap_link_original"]),
            state_slice_output_folder,
            f"{state}_sampled_rooftops_centroids_original_{slice_idx}",
            ["kml"],
        )

        # Save snapped points
        save_shapefiles(
            state_slice_snapped_gdf,
            state_slice_output_folder,
            f"{state}_sampled_rooftops_snapped_points_{slice_idx}",
            ["csv", "parquet"],
        )
        save_shapefiles(
            state_slice_snapped_gdf.drop(
                # drop kml unfriendly columns
                columns=["gmap_link_original", "gmap_link", "geometry_line", "geometry_original"]
            ),
            state_slice_output_folder,
            f"{state}_sampled_rooftops_snapped_points_{slice_idx}",
            ["kml"],
        )

        # Save lines
        save_shapefiles(
            state_slice_line_gdf.drop(
                # drop kml unfriendly columns
                columns=["gmap_link_original", "gmap_link"]
            ),
            state_slice_output_folder,
            f"{state}_sampled_rooftops_snapped_lines_{slice_idx}",
            ["parquet", "kml"],
        )
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.068298014750795.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1043' of field Maharashtra_sampled_rooftops_centroids_original_0.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'ward' of field Maharashtra_sampled_rooftops_centroids_original_0.longitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'No' of field Maharashtra_sampled_rooftops_centroids_original_0.State Code parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'Urban' of field Maharashtra_sampled_rooftops_centroids_original_0.Ward Code parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Invalid value 'GOOD - Ward boundary given as expected' for boolean field Maharashtra_sampled_rooftops_centroids_original_0.TV Boundary Given. Assuming it to be false.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.SubDistrict Boundary Given: Only 0 or 1 should be passed for a OFSTBoolean subtype. Considering non-zero value 27 as 1.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.069862206598341.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.06775859848705.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.067115296547676.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.069452239588294.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.069137202249486.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.068123704741144.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.071851710322623.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.066961765272783.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.066034391706861.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.074088426044579.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.068240627353649.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.068171905654211.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.06973363320974.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.072862001796032.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.074117717408459.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.074442110065387.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.06918680503064.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.072614538668152.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.069250810159133.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.071053660833389.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.066352341866221.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.071651658274.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.074018093231587.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.068532257520395.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.063135322874135.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1144' of field Maharashtra_sampled_rooftops_centroids_original_0.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.066353756120382.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.065254519433584.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.064162236637664.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.064613748496676.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.064649651017682.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.067360432639422.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.06192495768709.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.061791525781612.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.05990594133679.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.063652868501727.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.061336726319485.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.062903564078621.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.06076682340063.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.060470075933658.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.066154288757019.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.06517792038191.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.067562607476564.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.0625379386397.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.067641001301247.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.064133909732007.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.0660110462102.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.065083923367506.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.063958048622894.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.061547113085361.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.099958206629111.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1249' of field Maharashtra_sampled_rooftops_centroids_original_0.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.094261383121854.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.100985291701651.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.100987320266348.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.097587835507785.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.105420564107462.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.097674474968944.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.109140461450544.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.099613897771857.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.099740167772794.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.099727567163093.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.092081574994889.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.096536857623978.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.084895561284128.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.103861588321596.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.109424275558254.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.102160065445833.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.104327147747899.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.098917376134583.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.105093897868038.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.10112180666605.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.10311063283385.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.11113491586001.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.097668644303486.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.095351368649915.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.105911278229566.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1255' of field Maharashtra_sampled_rooftops_centroids_original_0.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.105079029593373.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.128154600260785.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.130211515014818.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.125826472417529.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.121347899315854.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.107923011734599.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.104946058582684.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.115278572905773.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.109463769978959.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.110515060708853.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.111778980135224.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.107519923645686.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.126587428358132.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.102400941810682.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.107994073787321.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.11042377818184.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.126211097992968.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.118664354271672.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.122799447870221.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.116513956143276.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.125804001678006.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.117813892968847.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.109019906115215.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.10695147196018.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.133088634050306.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1256' of field Maharashtra_sampled_rooftops_centroids_original_0.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.132748119095911.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.13050352564191.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.138999225999086.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.134150292642914.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.134280672073174.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.129203621636144.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.130994166373771.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.130710989141789.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.134289233700564.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.134085424144921.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.137172357970897.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.136471418245126.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.135100303325725.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.13477319297164.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.137497428851983.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.133826666329949.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.131895214245418.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.134826630029561.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.131238739381434.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.135572626205846.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.138515637623613.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.1324702773734.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.136641722002651.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.131639015294638.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.135365570492301.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1354' of field Maharashtra_sampled_rooftops_centroids_original_0.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.139236948397684.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.140214624879548.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.143354998197839.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.142010195323635.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.138274490194203.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.142314431193491.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.140002829239709.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.140812980746912.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.142136554245354.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.138722191034685.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.137150151331213.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.138820667567334.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.140825176949519.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.141227145658643.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.143567871487548.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.13437448146891.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.140598201908499.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.142664167428958.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.142368889498115.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.143880137126992.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.142421240641237.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_0.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.140028737276285.
#   ogr_write(
# ...
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_2.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.061738811188459.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_2.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.063440706490084.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_2.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.058512170205045.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_2.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.064511946800916.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_2.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.064281577510254.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_2.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.060039403535388.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_2.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.057838655473013.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_2.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.059878351051601.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_2.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.060233973777827.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_2.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.058789224789958.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_2.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.06347010955032.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_2.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.063028208346196.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_2.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.05954951103617.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_2.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.059158257464645.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_2.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.058747888497042.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_2.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.059716581348887.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_2.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.060554987433402.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_2.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.05904667498783.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_2.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.061212716881951.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_2.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.063508862153757.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_2.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.059868254926876.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_centroids_original_2.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.059413264631761.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1043' of field Maharashtra_sampled_rooftops_snapped_points_2.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'ward' of field Maharashtra_sampled_rooftops_snapped_points_2.longitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'No' of field Maharashtra_sampled_rooftops_snapped_points_2.State Code parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'Urban' of field Maharashtra_sampled_rooftops_snapped_points_2.Ward Code parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Invalid value 'GOOD - Ward boundary given as expected' for boolean field Maharashtra_sampled_rooftops_snapped_points_2.TV Boundary Given. Assuming it to be false.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_snapped_points_2.SubDistrict Boundary Given: Only 0 or 1 should be passed for a OFSTBoolean subtype. Considering non-zero value 27 as 1.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1144' of field Maharashtra_sampled_rooftops_snapped_points_2.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1249' of field Maharashtra_sampled_rooftops_snapped_points_2.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1255' of field Maharashtra_sampled_rooftops_snapped_points_2.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1256' of field Maharashtra_sampled_rooftops_snapped_points_2.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1354' of field Maharashtra_sampled_rooftops_snapped_points_2.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1357' of field Maharashtra_sampled_rooftops_snapped_points_2.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1458' of field Maharashtra_sampled_rooftops_snapped_points_2.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1459' of field Maharashtra_sampled_rooftops_snapped_points_2.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1562' of field Maharashtra_sampled_rooftops_snapped_points_2.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1978' of field Maharashtra_sampled_rooftops_snapped_points_2.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-2080' of field Maharashtra_sampled_rooftops_snapped_points_2.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-2179' of field Maharashtra_sampled_rooftops_snapped_points_2.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1043' of field Maharashtra_sampled_rooftops_snapped_lines_2.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'ward' of field Maharashtra_sampled_rooftops_snapped_lines_2.longitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'No' of field Maharashtra_sampled_rooftops_snapped_lines_2.State Code parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'Urban' of field Maharashtra_sampled_rooftops_snapped_lines_2.Ward Code parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Invalid value 'GOOD - Ward boundary given as expected' for boolean field Maharashtra_sampled_rooftops_snapped_lines_2.TV Boundary Given. Assuming it to be false.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field Maharashtra_sampled_rooftops_snapped_lines_2.SubDistrict Boundary Given: Only 0 or 1 should be passed for a OFSTBoolean subtype. Considering non-zero value 27 as 1.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1144' of field Maharashtra_sampled_rooftops_snapped_lines_2.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1249' of field Maharashtra_sampled_rooftops_snapped_lines_2.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1255' of field Maharashtra_sampled_rooftops_snapped_lines_2.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1256' of field Maharashtra_sampled_rooftops_snapped_lines_2.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1354' of field Maharashtra_sampled_rooftops_snapped_lines_2.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1357' of field Maharashtra_sampled_rooftops_snapped_lines_2.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1458' of field Maharashtra_sampled_rooftops_snapped_lines_2.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1459' of field Maharashtra_sampled_rooftops_snapped_lines_2.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1562' of field Maharashtra_sampled_rooftops_snapped_lines_2.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1978' of field Maharashtra_sampled_rooftops_snapped_lines_2.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-2080' of field Maharashtra_sampled_rooftops_snapped_lines_2.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-2179' of field Maharashtra_sampled_rooftops_snapped_lines_2.latitude_original parsed incompletely to real 0.
#   ogr_write(

# %% [markdown]
# ## Save per-PSU

# %%
for psu_id in tqdm(sampled_rooftops_organised_gdf["PSU ID"].unique()):

    # save original points
    selected_psu_original_gdf = sampled_rooftops_organised_gdf[
        sampled_rooftops_organised_gdf["PSU ID"] == psu_id
    ]

    # for folder name
    first_row = selected_psu_original_gdf.iloc[0]
    psu_type = first_row["PSU Type"]
    state_name = first_row["State Name"].strip().replace(" ", "_")
    district_name = first_row["District Name"].strip().replace(" ", "_")
    subdistrict_name = first_row["Subdistrict Name"].strip().replace(" ", "_")
    tv_code = int(first_row["TV Code"]) if pd.notna(first_row["TV Code"]) else None
    ward_code = int(first_row["Ward Code"]) if pd.notna(first_row["Ward Code"]) else None

    if psu_type == "ward":
        foldername = f"{state_name}_DIST_{district_name}_SUBDIST_{subdistrict_name}_TV_{tv_code}_WARD_{ward_code}_PSUID_{psu_id}"
    elif psu_type == "town_village":
        foldername = f"{state_name}_DIST_{district_name}_SUBDIST_{subdistrict_name}_TV_{tv_code}_PSUID_{psu_id}"
    elif psu_type == "subdistrict":
        foldername = f"{state_name}_DIST_{district_name}_SUBDIST_{subdistrict_name}_PSUID_{psu_id}"
    else:
        raise ValueError(f"Unknown PSU Type: {psu_type}")
    psu_output_folder = OUTPUT_DATA_DIR / "01. Sampled Rooftop Data" / "PSU-Level" / foldername
    psu_output_folder.mkdir(parents=True, exist_ok=True)

    save_shapefiles(
        selected_psu_original_gdf,
        psu_output_folder,
        f"{psu_id}_sampled_rooftops_centroids_original",
        ["csv", "parquet"],
    )
    save_shapefiles(
        selected_psu_original_gdf.drop(
            # drop kml unfriendly columns
            columns=["gmap_link_original"]
        ),
        psu_output_folder,
        f"{psu_id}_sampled_rooftops_centroids_original",
        ["kml"],
    )

    # Save snapped points
    selected_psu_snapped_gdf = sampled_rooftops_snapped_gdf[
        sampled_rooftops_snapped_gdf["PSU ID"] == psu_id
    ].drop(
        columns=[
            "geometry_original",
            "geometry_line",
        ]
    )
    save_shapefiles(
        selected_psu_snapped_gdf,
        psu_output_folder,
        f"{psu_id}_sampled_rooftops_snapped_points",
        ["csv", "parquet"],
    )
    save_shapefiles(
        selected_psu_snapped_gdf.drop(
            # drop kml unfriendly columns
            columns=["gmap_link_original", "gmap_link"]
        ),
        psu_output_folder,
        f"{psu_id}_sampled_rooftops_snapped_points",
        ["kml"],
    )

    # Save lines
    selected_psu_sampled_rooftops_line_gdf = sampled_rooftops_line_gdf[
        sampled_rooftops_line_gdf["PSU ID"] == psu_id
    ]
    save_shapefiles(
        selected_psu_sampled_rooftops_line_gdf.drop(
            # drop kml unfriendly columns
            columns=["gmap_link_original", "gmap_link"]
        ),
        psu_output_folder,
        f"{psu_id}_sampled_rooftops_snapped_lines",
        ["parquet", "kml"],
    )
# Out:
#   0%|          | 0/13 [00:00<?, ?it/s]
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Layer name 'WARD_802794-1043_sampled_rooftops_centroids_original' adjusted to 'WARD_802794_1043_sampled_rooftops_centroids_original' for XML validity.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.068298014750795.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1043' of field WARD_802794_1043_sampled_rooftops_centroids_original.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'ward' of field WARD_802794_1043_sampled_rooftops_centroids_original.longitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'No' of field WARD_802794_1043_sampled_rooftops_centroids_original.State Code parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'Urban' of field WARD_802794_1043_sampled_rooftops_centroids_original.Ward Code parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Invalid value 'GOOD - Ward boundary given as expected' for boolean field WARD_802794_1043_sampled_rooftops_centroids_original.TV Boundary Given. Assuming it to be false.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.SubDistrict Boundary Given: Only 0 or 1 should be passed for a OFSTBoolean subtype. Considering non-zero value 27 as 1.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.069862206598341.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.06775859848705.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.067115296547676.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.069452239588294.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.069137202249486.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.068123704741144.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.071851710322623.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.066961765272783.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.066034391706861.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.074088426044579.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.068240627353649.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.068171905654211.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.06973363320974.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.072862001796032.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.074117717408459.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.074442110065387.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.06918680503064.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.072614538668152.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.069250810159133.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.071053660833389.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.066352341866221.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.071651658274.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.074018093231587.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.068532257520395.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.068106174384649.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.069333150231646.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.068980462126383.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.066553058513925.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.068894454131854.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.072044058473868.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.071420626064469.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.069914607169196.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.067724731670594.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.071592640251922.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.073585795333198.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.073993944301467.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.065637822023294.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.068551628781293.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.074613046604334.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.068174053097859.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.068761060271548.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.070393864114102.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.072272451830695.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.068757116224866.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.067846895754275.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.074542521224583.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.072742061905288.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.07313632741484.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.070359975875963.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.067725960359098.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.072278438342693.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.074118728654657.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.064473578470711.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.069613796939336.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.067054156713365.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.067551200981118.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.065874354567562.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.071677683752853.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.069394741429601.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.06479031143639.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.074370581234014.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.068000219492642.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.073582798009777.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.074378393798426.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.068305869128753.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.070995206748051.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.073439078733308.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.074268084956891.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.0740416554546.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.073480744825019.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.070395597955184.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.069565509244388.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.07031943259252.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.072893737850116.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Layer name 'WARD_802794-1043_sampled_rooftops_snapped_points' adjusted to 'WARD_802794_1043_sampled_rooftops_snapped_points' for XML validity.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1043' of field WARD_802794_1043_sampled_rooftops_snapped_points.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'ward' of field WARD_802794_1043_sampled_rooftops_snapped_points.longitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'No' of field WARD_802794_1043_sampled_rooftops_snapped_points.State Code parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'Urban' of field WARD_802794_1043_sampled_rooftops_snapped_points.Ward Code parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Invalid value 'GOOD - Ward boundary given as expected' for boolean field WARD_802794_1043_sampled_rooftops_snapped_points.TV Boundary Given. Assuming it to be false.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_snapped_points.SubDistrict Boundary Given: Only 0 or 1 should be passed for a OFSTBoolean subtype. Considering non-zero value 27 as 1.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Layer name 'WARD_802794-1043_sampled_rooftops_snapped_lines' adjusted to 'WARD_802794_1043_sampled_rooftops_snapped_lines' for XML validity.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1043' of field WARD_802794_1043_sampled_rooftops_snapped_lines.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'ward' of field WARD_802794_1043_sampled_rooftops_snapped_lines.longitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'No' of field WARD_802794_1043_sampled_rooftops_snapped_lines.State Code parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'Urban' of field WARD_802794_1043_sampled_rooftops_snapped_lines.Ward Code parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Invalid value 'GOOD - Ward boundary given as expected' for boolean field WARD_802794_1043_sampled_rooftops_snapped_lines.TV Boundary Given. Assuming it to be false.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1043_sampled_rooftops_snapped_lines.SubDistrict Boundary Given: Only 0 or 1 should be passed for a OFSTBoolean subtype. Considering non-zero value 27 as 1.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Layer name 'WARD_802794-1144_sampled_rooftops_centroids_original' adjusted to 'WARD_802794_1144_sampled_rooftops_centroids_original' for XML validity.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1144_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.063135322874135.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-1144' of field WARD_802794_1144_sampled_rooftops_centroids_original.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'ward' of field WARD_802794_1144_sampled_rooftops_centroids_original.longitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'No' of field WARD_802794_1144_sampled_rooftops_centroids_original.State Code parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'Urban' of field WARD_802794_1144_sampled_rooftops_centroids_original.Ward Code parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Invalid value 'GOOD - Ward boundary given as expected' for boolean field WARD_802794_1144_sampled_rooftops_centroids_original.TV Boundary Given. Assuming it to be false.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1144_sampled_rooftops_centroids_original.SubDistrict Boundary Given: Only 0 or 1 should be passed for a OFSTBoolean subtype. Considering non-zero value 27 as 1.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1144_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.066353756120382.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1144_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.065254519433584.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1144_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.064162236637664.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1144_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.064613748496676.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1144_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.064649651017682.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1144_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.067360432639422.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1144_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.06192495768709.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1144_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.061791525781612.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1144_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.05990594133679.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1144_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.063652868501727.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1144_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.061336726319485.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1144_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.062903564078621.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1144_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.06076682340063.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1144_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.060470075933658.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1144_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.066154288757019.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1144_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.06517792038191.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1144_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.067562607476564.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1144_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.0625379386397.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1144_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.067641001301247.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1144_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.064133909732007.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1144_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.0660110462102.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1144_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.065083923367506.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1144_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.063958048622894.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1144_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.061547113085361.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1144_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.063884723188458.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1144_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.061337972889859.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1144_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.067405122298982.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1144_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.061958429032014.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1144_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.067077973306599.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1144_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.064400029992584.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1144_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.059919438670089.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1144_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.066477522577916.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1144_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.061707509216621.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1144_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.066178897325372.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1144_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.059771353778835.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1144_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.061930399068249.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1144_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.06486451280151.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1144_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.065773716842532.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1144_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.06645894101883.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1144_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.064207519111942.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1144_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.060835730858916.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1144_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.065355496358382.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1144_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.064658369119552.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1144_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.064317470960617.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1144_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.063549437117697.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1144_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.061724550424223.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1144_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.060321760137008.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1144_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.065277168607949.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1144_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.061232603737533.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1144_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.066878411704472.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1144_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.060454552762668.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1144_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.062413832468835.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1144_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.060038425074303.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1144_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.062222329398441.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1144_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.066484488869282.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_1144_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.066695330823784.
#   ogr_write(
# ...
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_2179_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.059228634159009.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_2179_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.06138824995973.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_2179_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.059779765688535.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_2179_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.061516424807422.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_2179_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.059366328483787.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_2179_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.059305547971515.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_2179_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.058564682470493.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_2179_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.05956216924233.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_2179_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.058685753422012.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_2179_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.064603695583692.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_2179_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.060007178312109.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_2179_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.059171400285067.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_2179_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.059686610979711.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_2179_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.06000834249966.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_2179_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.059598076992142.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_2179_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.061025407435377.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_2179_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.059192383067334.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_2179_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.058663649648967.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_2179_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.061738811188459.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_2179_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.063440706490084.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_2179_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.058512170205045.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_2179_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.064511946800916.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_2179_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.064281577510254.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_2179_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.060039403535388.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_2179_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.057838655473013.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_2179_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.059878351051601.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_2179_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.060233973777827.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_2179_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.058789224789958.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_2179_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.06347010955032.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_2179_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.063028208346196.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_2179_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.05954951103617.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_2179_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.059158257464645.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_2179_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.058747888497042.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_2179_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.059716581348887.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_2179_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.060554987433402.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_2179_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.05904667498783.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_2179_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.061212716881951.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_2179_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.063508862153757.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_2179_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.059868254926876.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_2179_sampled_rooftops_centroids_original.Rooftop PSU ID Numeric: Lossy conversion occurred when trying to set 64 bit integer field from real value 19.059413264631761.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Layer name 'WARD_802794-2179_sampled_rooftops_snapped_points' adjusted to 'WARD_802794_2179_sampled_rooftops_snapped_points' for XML validity.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-2179' of field WARD_802794_2179_sampled_rooftops_snapped_points.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'ward' of field WARD_802794_2179_sampled_rooftops_snapped_points.longitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'No' of field WARD_802794_2179_sampled_rooftops_snapped_points.State Code parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'Urban' of field WARD_802794_2179_sampled_rooftops_snapped_points.Ward Code parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Invalid value 'GOOD - Ward boundary given as expected' for boolean field WARD_802794_2179_sampled_rooftops_snapped_points.TV Boundary Given. Assuming it to be false.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_2179_sampled_rooftops_snapped_points.SubDistrict Boundary Given: Only 0 or 1 should be passed for a OFSTBoolean subtype. Considering non-zero value 27 as 1.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Layer name 'WARD_802794-2179_sampled_rooftops_snapped_lines' adjusted to 'WARD_802794_2179_sampled_rooftops_snapped_lines' for XML validity.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'WARD_802794-2179' of field WARD_802794_2179_sampled_rooftops_snapped_lines.latitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'ward' of field WARD_802794_2179_sampled_rooftops_snapped_lines.longitude_original parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'No' of field WARD_802794_2179_sampled_rooftops_snapped_lines.State Code parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Value 'Urban' of field WARD_802794_2179_sampled_rooftops_snapped_lines.Ward Code parsed incompletely to real 0.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Invalid value 'GOOD - Ward boundary given as expected' for boolean field WARD_802794_2179_sampled_rooftops_snapped_lines.TV Boundary Given. Assuming it to be false.
#   ogr_write(
# /Users/amiremami/.pyenv/versions/geospatial/lib/python3.12/site-packages/pyogrio/raw.py:723: RuntimeWarning: Field WARD_802794_2179_sampled_rooftops_snapped_lines.SubDistrict Boundary Given: Only 0 or 1 should be passed for a OFSTBoolean subtype. Considering non-zero value 27 as 1.
#   ogr_write(
